# %% [markdown]
# <a href="https://colab.research.google.com/github/win7/Template_ML-Classification/blob/main/Classifier_Codon_MLflow_tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import multiprocessing
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
cores
LOCAL = True

# %% [markdown]
# ### **Install**

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Requirement already satisfied: ipython-autotime in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (0.3.1)
# Requirement already satisfied: ipython in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython-autotime) (8.4.0)
# Requirement already satisfied: traitlets>=5 in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (5.2.2.post1)
# Requirement already satisfied: setuptools>=18.5 in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (44.0.0)
# Requirement already satisfied: jedi>=0.16 in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (0.18.1)
# Requirement already satisfied: backcall in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: decorator in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (5.1.1)
# Requirement already satisfied: stack-data in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (0.3.0)
# Requirement already satisfied: pickleshare in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: matplotlib-inline in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from ipython->ipython-autotime) (2.12.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: asttokens in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from stack-data->ipython->ipython-autotime) (2.0.5)
# Requirement already satisfied: pure-eval in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from stack-data->ipython->ipython-autotime) (0.2.2)
# Requirement already satisfied: executing in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from stack-data->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: six in ./VirtualEnv_Embedding_3.9/lib/python3.8/site-packages (from asttokens->stack-data->ipython->ipython-autotime) (1.16.0)
# time: 944 µs (started: 2022-06-26 14:14:09 -05:00)

# %% [markdown]
# ### **Imports**

# %%
""" from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import RandomOverSampler
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from imblearn.ensemble import BalancedBaggingClassifier """
from pprint import pprint
from sklearn import preprocessing
from sklearn.base import clone
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, VotingClassifier
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.feature_selection import chi2
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.manifold import TSNE
from sklearn.metrics import adjusted_rand_score, rand_score, confusion_matrix, \
precision_score, accuracy_score, recall_score, classification_report, roc_auc_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, HalvingGridSearchCV,  \
HalvingRandomSearchCV, train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from scipy.stats import randint

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import mlflow
from  mlflow.tracking import MlflowClient

# %matplotlib inline
# Out:
# time: 5.08 ms (started: 2022-06-26 18:08:49 -05:00)

# %% [markdown]
# ### **Functions**

# %%
def log_run(gridsearch, experiment_name, model_name, run_index, conda_env, tags={}):
    """Logging of cross validation results to mlflow tracking server
    
    Args:
        experiment_name (str): experiment name
        model_name (str): Name of the model
        run_index (int): Index of the run (in Gridsearch)
        conda_env (str): A dictionary that describes the conda environment (MLFlow Format)
        tags (dict): Dictionary of extra data and tags (usually features)
    """
    
    cv_results = gridsearch.cv_results_
    with mlflow.start_run(run_name=str(run_index)) as run:  

        mlflow.log_param("folds", gridsearch.cv)

        print("Logging parameters")
        params = list(gridsearch.param_grid.keys())
        for param in params:
            mlflow.log_param(param, cv_results["param_%s" % param][run_index])

        print("Logging metrics")
        for score_name in [score for score in cv_results if "mean_test" in score]:
            mlflow.log_metric(score_name, cv_results[score_name][run_index])
            mlflow.log_metric(score_name.replace("mean","std"), cv_results[score_name.replace("mean","std")][run_index])

        print("Logging model")        
        mlflow.sklearn.log_model(gridsearch.best_estimator_, model_name, conda_env=conda_env)

        print("Logging CV results matrix")
        tempdir = tempfile.TemporaryDirectory().name
        os.mkdir(tempdir)
        timestamp = datetime.now().isoformat().split(".")[0].replace(":", ".")
        filename = "%s-%s-cv_results.csv" % (model_name, timestamp)
        csv = os.path.join(tempdir, filename)
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            pd.DataFrame(cv_results).to_csv(csv, index=False)
        
        mlflow.log_artifact(csv, "cv_results") 

        print("Logging extra data related to the experiment")
        mlflow.set_tags(tags) 

        run_id = run.info.run_uuid
        experiment_id = run.info.experiment_id
        mlflow.end_run()
        print(mlflow.get_artifact_uri())
        print("runID: %s" % run_id)

# %% [markdown]
# ####load_dataset

# %%
def load_dataset(file_name, test=False):
  df = pd.read_csv(file_name)

  # Rename columns name
  if test:
    columns_name = ["Id", "Edad", "Trabajo", "Estado Civil", "Educación", "Crédito por Defecto",
                    "Préstamo Vivienda", "Préstamo Personal", "Contacto", "Mes", "Día Semana",
                    "Duración", "Cantidad Contactos Realizados", "Cantidad Días desde Último Contacto",
                    "Cantidad Contactos Previos Realizados", "Resultado Campaña Anterior", "Tasa Variación Empleo",
                    "Índice Precios Consumidor", "Índice Confianza Consumidor", "Tasa Interes 3 meses",
                    "Cantidad Empleados"]
  else:
    columns_name = ["Id", "Edad", "Trabajo", "Estado Civil", "Educación", "Crédito por Defecto",
                  "Préstamo Vivienda", "Préstamo Personal", "Contacto", "Mes", "Día Semana",
                  "Duración", "Cantidad Contactos Realizados", "Cantidad Días desde Último Contacto",
                  "Cantidad Contactos Previos Realizados", "Resultado Campaña Anterior", "Tasa Variación Empleo",
                  "Índice Precios Consumidor", "Índice Confianza Consumidor", "Tasa Interes 3 meses",
                  "Cantidad Empleados", "Subscripción Depósito"]
  
  df.columns = columns_name

  return df

# %% [markdown]
# ####get_column_type

# %%
def get_column_type(df):
  # Get column with varible categorical and numeric
  column_categorical = []
  column_numerical = []
  for column in df.columns:
    if df[column].dtype == "object":
      column_categorical.append(column)
    else:
      column_numerical.append(column)
  return column_categorical, column_numerical

# %% [markdown]
# ####preview_dataset

# %%
def preview_dataset(df):
  # Get column with varible categorical and numeric
  column_categorical, column_numerical = get_column_type(df)  

  # Count values in categorical columns
  for column in column_categorical:
      print("\033[1mColumn name: {}\033[0m".format(column))
      # print(df[column].value_counts(ascending=True, dropna=False, normalize=True))
      print(df[column].value_counts(ascending=False, dropna=False))
      print()

  for column in column_numerical:
      negatives = len(df.loc[df[column] < 0])
      zeros = len(df.loc[df[column] == 0])
      positives = len(df.loc[df[column] > 0])
      nans = df[column].isnull().sum()

      print("\033[1mColumn name: {}\033[0m".format(column))
      print(f"NANs: {nans}")
      print(f"Negatives: {negatives}")
      print(f"Zeros: {zeros}")
      print(f"Positives: {positives}\n")
      # print(df[column].value_counts(ascending=True, dropna=False, normalize=True))
      print(df[column].value_counts(ascending=False, dropna=False))
      print()

      fig, axs = plt.subplots(2)
      fig.suptitle("Hist-Boxplot")
      axs[0].hist(df[column])
      axs[0].grid()
      axs[1].boxplot(df[column])
      axs[1].grid()
      plt.show()

# %%
import numpy as np
from sklearn.impute import KNNImputer
X = [[1, 2, np.nan], [3, 4, 1], [2, 6, 1], [8, 8, 1]]

data = {'Name':[1, 2, 3, 4, 5],
        'Age':[20, np.nan, 19, 0, 21],
        'Salary':[10, 15, 20, np.nan, 40],}
 
# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
#    Name   Age  Salary
# 0     1  20.0    10.0
# 1     2   NaN    15.0
# 2     3  19.0    20.0
# 3     4   0.0     NaN
# 4     5  21.0    40.0

# %%
imputer = KNNImputer(n_neighbors=2)
data = imputer.fit_transform(df)

# Create the pandas DataFrame
df1 = pd.DataFrame(data, columns = ['Name', 'Age', 'Salary'])
df1
# Out:
#    Name   Age  Salary
# 0   1.0  20.0    10.0
# 1   2.0   9.5    15.0
# 2   3.0  19.0    20.0
# 3   4.0   0.0    17.5
# 4   5.0  21.0    40.0

# %% [markdown]
# ####imputation

# %%
def imputation(df, option=1):
  """
  Options
    1: mean
    2: median
    3: most_frequent
    4: zeros
    5: KNN
  """
  # df.fillna(value={"column1": 1, ...})

  """ columns = df.columns[df.isnull().any()].tolist()

  for column in columns:
    mode = df[column].mode()[0]
    median = df[column].median()
    mean = int(df[column].mean())
    options = [mode, median, mean]
    df[column].fillna(options[key], inplace=True) """

  if option == 1:
    imputer = SimpleImputer(missing_values=np.nan, strategy="mean", add_indicator=False)
  elif option == 2:
    imputer = SimpleImputer(missing_values=np.nan, strategy="median", add_indicator=False)
  elif option == 3:
    imputer = SimpleImputer(missing_values=np.nan, strategy="most_frequent", add_indicator=False)
  elif option == 4:
    imputer = SimpleImputer(missing_values=np.nan, add_indicator=False, strategy="constant", fill_value=0)
  elif option == 5:
    imputer = KNNImputer(missing_values=np.nan, add_indicator=False, n_neighbors=4)
  else:
    imputer = SimpleImputer(missing_values=np.nan, strategy="most_frequent", add_indicator=False)
    
  data = imputer.fit_transform(df)
  df_ = pd.DataFrame(data.tolist(), columns=df.columns)

  return df_

# %% [markdown]
# ####preprocessing1

# %%
def preprocessing1(df, option_imputation):
  # Check missing values
  """ print("\033[1mMissing values\033[0m")
  print(df.isnull().sum())

  # Count unique values by columns
  print("\033[1mCount unique values\033[0m")
  print(df.nunique())
  print() """

  # Replace
  df.replace(to_replace="valor_que_falta", value=np.nan, inplace=True)
  df.replace(to_replace="inexistente", value=np.nan, inplace=True)
  df.replace(to_replace="no", value=0, inplace=True)
  df.replace(to_replace="si", value=1, inplace=True)

  # Id
  try:
    df.drop(columns=["Id"], inplace=True)
  except:
    pass

  # Edad
  df.loc[df["Edad"] > 50, "Edad"] = df["Edad"].median()

  # Trabajo
  df["Trabajo"] = df["Trabajo"].map({"desempleado": 0, "estudiante": 1,
                                     "empleada_domestica": 2, "empleado_ por_cuenta_propia": 2,
                                     "emprendedor": 2, "servicios": 2, "tecnico":2, 
                                     "trabajador_industria": 2, "administración": 2, 
                                     "administrador": 2,  "retirado": 3})
  # df["Trabajo"] = df["Trabajo"].astype("category")

  # Estado Civil
  df["Estado Civil"] = df["Estado Civil"].map({"soltero": 0, "casado": 1, "divorciado": 2})

  # Educación
  df["Educación"] = df["Educación"].map({"analfabeto": 0, "primaria_3_grado": 1,
                                          "primaria_4_grado": 1, "primaria_6_grado": 1,
                                          "secundaria_completa": 2, "curso_profesional": 3,
                                          "grado_universitario": 4})

  # Crédito por Defecto

  # Préstamo Vivienda

  # Préstamo Personal

  # Contacto
  df["Contacto"] = df["Contacto"].map({"telefono": 0, "celular": 1})

  # Mes
  df["Mes"] = df["Mes"].map({"enero": 1, "febrero": 2, "marzo": 3, "abril": 4, 
                             "mayo": 5, "junio": 6, "julio": 7, "agosto": 8, 
                             "septiembre": 9, "octubre": 10, "noviembre": 11, 
                             "diciembre": 12})
  # Día Semana
  df["Día Semana"] = df["Día Semana"].map({"lunes": 1, "martes": 2, "miercoles": 3, 
                                           "jueves": 4, "viernes": 5})
  # Duración

  # Cantidad Contactos Realizado

  # Cantidad Días desde Último Contacto
  df["Cantidad Días desde Último Contacto"].replace(to_replace=0, value=1, inplace=True)
  df["Cantidad Días desde Último Contacto"].replace(to_replace=999, value=0, inplace=True)

  # Cantidad Contactos Previos Realizados

  # Resultado Campaña Anterior
  df["Resultado Campaña Anterior"] = df["Resultado Campaña Anterior"].map({"fallido": 0, 
                                                                           "exitoso": 1})
  # Tasa Variación Empleo

  # Índice Precios Consumidor

  # Índice Confianza Consumidor

  # Tasa Interes 3 meses
  
  # Cantidad Empleados
  
  # Subscripción Depósito

  # Testing Update
  """ try:
    df.drop(columns=["Mes", "Día Semana"], inplace=True)
  except:
    pass """

  # Imputation
  df_ = imputation(df, option_imputation)
      
  return df_

# %% [markdown]
# ####preprocessing2

# %%
def preprocessing2(df):
  # Check missing values
  """ print("\033[1mMissing values\033[0m")
  print(df.isnull().sum())

  # Count unique values by columns
  print("\033[1mCount unique values\033[0m")
  print(df.nunique())
  print() """

  # Replace
  # df.replace(to_replace="valor_que_falta", value=np.nan, inplace=True)

  # Id
  try:
    df.drop(columns=["Id"], inplace=True)
  except:
    pass

  # Edad
  df.loc[df["Edad"] > 50, "Edad"] = df["Edad"].median()

  # Trabajo
  df["Trabajo"].replace(to_replace=["empleada_domestica",
                                    "empleado_ por_cuenta_propia",
                                    "emprendedor",
                                    "servicios",
                                    "tecnico",
                                    "trabajador_industria",
                                    "administrador",
                                    "administración"], value ="empleado", inplace=True)
  # df["Trabajo"] = df["Trabajo"].astype("category")

  # Estado Civil

  # Educación
  df["Educación"].replace(to_replace =["primaria_6_grado",
                                      "primaria_4_grado",
                                      "primaria_3_grado"], value="primaria", inplace=True)
  
  # Crédito por Defecto

  # Préstamo Vivienda

  # Préstamo Personal

  # Contacto

  # Mes
  
  # Día Semana
  
  # Duración

  # Cantidad Contactos Realizado

  # Cantidad Dias desde Último Contacto
  df["Cantidad Días desde Último Contacto"].replace(to_replace=0, value=1, inplace=True)
  df["Cantidad Días desde Último Contacto"].replace(to_replace=999, value=0, inplace=True)

  # Cantidad Días desde Último Contacto

  # Cantidad Contactos Previos Realizados

  # Resultado Campaña Anterior
  
  # Tasa Variación Empleo

  # Índice Precios Consumidor

  # Índice Confianza Consumidor

  # Tasa Interes 3 meses
  
  # Cantidad Empleados
  
  # Subscripción Depósito
  try:
      df["Subscripción Depósito"] = df["Subscripción Depósito"].map({"no": 0, "si": 1})
  except:
    pass

  # Imputation
  # df_ = imputation(df, option_imputation)

  # One-hot
  df_ = pd.get_dummies(df)#, columns=column_categorical)
  
  return df_

# %% [markdown]
# ####preprocessing3

# %%
def preprocessing3(df, option_imputation):
  # Check missing values
  """ print("\033[1mMissing values\033[0m")
  print(df.isnull().sum())

  # Count unique values by columns
  print("\033[1mCount unique values\033[0m")
  print(df.nunique())
  print() """

  # Replace
  df.replace(to_replace="valor_que_falta", value=np.nan, inplace=True)
  df.replace(to_replace="inexistente", value=np.nan, inplace=True)

  # Id
  try:
    df.drop(columns=["Id"], inplace=True)
  except:
    pass

  # Edad
  df.loc[df["Edad"] > 50, "Edad"] = df["Edad"].median()

  # Trabajo
  df["Trabajo"].replace(to_replace=["empleada_domestica",
                                    "empleado_ por_cuenta_propia",
                                    "emprendedor",
                                    "servicios",
                                    "tecnico",
                                    "trabajador_industria",
                                    "administrador",
                                    "administración"], value ="empleado", inplace=True)
  # df["Trabajo"] = df["Trabajo"].astype("category")

  # Estado Civil

  # Educación
  df["Educación"].replace(to_replace =["primaria_6_grado",
                                      "primaria_4_grado",
                                      "primaria_3_grado"], value="primaria", inplace=True)
  
  # Crédito por Defecto

  # Préstamo Vivienda

  # Préstamo Personal

  # Contacto

  # Mes
  
  # Día Semana
  
  # Duración

  # Cantidad Contactos Realizado

  # Cantidad Días desde Último Contacto
  df["Cantidad Días desde Último Contacto"].replace(to_replace=0, value=1, inplace=True)
  df["Cantidad Días desde Último Contacto"].replace(to_replace=999, value=0, inplace=True)

  # Cantidad Días desde Último Contacto

  # Cantidad Contactos Previos Realizados

  # Resultado Campaña Anterior
  
  # Tasa Variación Empleo

  # Índice Precios Consumidor

  # Índice Confianza Consumidor

  # Tasa Interes 3 meses
  
  # Cantidad Empleados
  
  # Subscripción Depósito
  try:
      df["Subscripción Depósito"] = df["Subscripción Depósito"].map({"no": 0, "si": 1})
  except:
    pass

  # Imputation
  df_ = imputation(df, option_imputation) 

  # One-hot
  df_ = pd.get_dummies(df_)#, columns=column_categorical)
  
  return df_

# %% [markdown]
# ####preprocessing4

# %%
def preprocessing4(df, option_imputation):
  # Check missing values
  """ print("\033[1mMissing values\033[0m")
  print(df.isnull().sum())

  # Count unique values by columns
  print("\033[1mCount unique values\033[0m")
  print(df.nunique())
  print() """

  # column_categorical,_ = get_column_type(df)
  # print(column_categorical)

  # Replace
  #  df.replace(to_replace="valor_que_falta", value=np.nan, inplace=True)
  df.replace(to_replace="inexistente", value=np.nan, inplace=True)
  df.replace(to_replace="no", value=0, inplace=True)
  df.replace(to_replace="si", value=1, inplace=True)

  # Id
  try:
    df.drop(columns=["Id"], inplace=True)
  except:
    pass

  # Edad
  df.loc[df["Edad"] > 50, "Edad"] = df["Edad"].median()

  # Trabajo
  """ df["Trabajo"].replace(to_replace=["empleada_domestica",
                                    "empleado_ por_cuenta_propia",
                                    "emprendedor",
                                    "servicios",
                                    "tecnico",
                                    "trabajador_industria",
                                    "administrador",
                                    "administración"], value ="empleado", inplace=True) """
  # df["Trabajo"] = df["Trabajo"].astype("category")

  # Estado Civil

  # Educación
  """ df["Educación"].replace(to_replace =["primaria_6_grado",
                                      "primaria_4_grado",
                                      "primaria_3_grado"], value="primaria", inplace=True)"""
  
  # Crédito por Defecto

  # Préstamo Vivienda

  # Préstamo Personal

  # Contacto

  # Mes
  
  # Día Semana
  
  # Duración

  # Cantidad Contactos Realizado

  # Cantidad Días desde Último Contacto
  df["Cantidad Días desde Último Contacto"].replace(to_replace=0, value=1, inplace=True)
  df["Cantidad Días desde Último Contacto"].replace(to_replace=999, value=0, inplace=True)

  # Cantidad Días desde Último Contacto

  # Cantidad Contactos Previos Realizados

  # Resultado Campaña Anterior
  
  # Tasa Variación Empleo

  # Índice Precios Consumidor

  # Índice Confianza Consumidor

  # Tasa Interes 3 meses
  
  # Cantidad Empleados
  
  # Subscripción Depósito

  # Imputation
  df_ = imputation(df, option_imputation)

  # One-hot
  df_ = pd.get_dummies(df_, drop_first=True) # , columns=column_categorical)
  return df_

# %% [markdown]
# ####preprocessing5

# %%
def preprocessing5(df, option_imputation):
  # Check missing values
  """ print("\033[1mMissing values\033[0m")
  print(df.isnull().sum())

  # Count unique values by columns
  print("\033[1mCount unique values\033[0m")
  print(df.nunique())
  print() """

  # column_categorical,_ = get_column_type(df)
  # print(column_categorical)

  # Replace
  df.replace(to_replace="valor_que_falta", value=np.nan, inplace=True)
  df.replace(to_replace="inexistente", value=np.nan, inplace=True)
  df.replace(to_replace="no", value=0, inplace=True)
  df.replace(to_replace="si", value=1, inplace=True)

  # Id
  try:
    df.drop(columns=["Id"], inplace=True)
  except:
    pass

  # Edad
  df.loc[df["Edad"] > 50, "Edad"] = df["Edad"].median()

  # Trabajo
  df["Trabajo"].replace(to_replace=["empleada_domestica",
                                    "empleado_ por_cuenta_propia",
                                    "emprendedor",
                                    "servicios",
                                    "tecnico",
                                    "trabajador_industria",
                                    "administrador",
                                    "administración"], value ="empleado", inplace=True)
  # df["Trabajo"] = df["Trabajo"].astype("category")

  # Estado Civil

  # Educación
  df["Educación"].replace(to_replace =["primaria_6_grado",
                                      "primaria_4_grado",
                                      "primaria_3_grado"], value="primaria", inplace=True)
  
  # Crédito por Defecto

  # Préstamo Vivienda

  # Préstamo Personal

  # Contacto

  # Mes
  
  # Día Semana
  
  # Duración

  # Cantidad Contactos Realizado

  # Cantidad Días desde Último Contacto
  df["Cantidad Días desde Último Contacto"].replace(to_replace=0, value=1, inplace=True)
  df["Cantidad Días desde Último Contacto"].replace(to_replace=999, value=0, inplace=True)

  # Cantidad Días desde Último Contacto

  # Cantidad Contactos Previos Realizados

  # Resultado Campaña Anterior
  
  # Tasa Variación Empleo

  # Índice Precios Consumidor

  # Índice Confianza Consumidor

  # Tasa Interes 3 meses
  
  # Cantidad Empleados
  
  # Subscripción Depósito

  # Imputation
  # df_ = imputation(df, option_imputation)

  # One-hot
  # df_ = pd.get_dummies(df_) # , columns=column_categorical)
  return df

# %% [markdown]
# ####correlation

# %%
def correlation(df):
  # Matrix correlation
  corr = df.corr()
  corr.style.background_gradient(cmap="coolwarm")

# %% [markdown]
# ####plot_hist

# %%
def plot_hist(df, option=1):
  # Visualization dataset
  w = 3
  h = 3
  if option == 1:
    df.hist(figsize=(24, 24))
  else:
    width = 15
    height = 20

    plt.style.use("default")
    figure, axes = plt.subplots(nrows=6, ncols=4, figsize=(width, height))

    for column, axe in zip(df, axes.flatten()):
        sns.distplot(df[column], ax=axe)
    plt.tight_layout()

# %% [markdown]
# ####train_valid_test_split

# %%
def train_valid_test_split(df, target):
  # Splitting data
  X = df.drop(target, axis=1)
  y = df[target]

  # Split the data in 80:10:10 for train:valid:test dataset
  train_size = 0.8
  test_size = 0.5
  X_train, X_rem, y_train, y_rem = train_test_split(X, y, train_size=0.8, stratify=y, random_state=0)
  X_valid, X_test, y_valid, y_test = train_test_split(X_rem, y_rem, test_size=0.5, stratify=y_rem, random_state=0)

  print(X_train.shape), print(y_train.shape)
  print(X_valid.shape), print(y_valid.shape)
  print(X_test.shape), print(y_test.shape)

  return X_train, X_valid, X_test, y_train, y_valid, y_test

# %%
def train_test_split_(df, target):
  # Splitting data
  X = df.drop(target, axis=1)
  y = df[target]

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=0)

  return X_train, X_test, y_train, y_test

# %% [markdown]
# ####transformation

# %%
def transformation(X_train, X_test, option=1):
  # Transformation
  """
  Options
    1: RobustScaler
    2: StandardScaler
    3: QuantileTransformer
    4: MinMaxScaler
    5: Normalizer
  """
  if option == 1:
    scaler = preprocessing.RobustScaler().fit(X_train)
  elif option == 2:
    scaler = preprocessing.StandardScaler().fit(X_train)
  elif option == 3:
    scaler = preprocessing.QuantileTransformer(random_state=0).fit(X_train)
  elif option == 4:
    scaler = preprocessing.MinMaxScaler().fit(X_train)
  elif option == 5:
    scaler = preprocessing.Normalizer().fit(X_train)
  else:
    scaler = preprocessing.StandardScaler().fit(X_train)

  X_train = scaler.transform(X_train)
  X_test = scaler.transform(X_test)
  return X_train, X_test

# %% [markdown]
# ####feature_selection

# %%
def feature_selection(X_train, y_train, X_test, components=3):
  # Univariate feature selection
  # selector = SelectKBest(f_classif, k=k).fit(X_train, y_train)
  selector = PCA(n_components=components).fit(X_train)
  # selector = TSNE(n_components=k, method="exact").fit(X_train)

  X_train = selector.transform(X_train)
  X_test = selector.transform(X_test)

  return X_train, X_test

# %% [markdown]
# ####validation

# %%
def validation1(model, X_test, y_test):
  y_pred = model.predict(X_test)

  accuracy = accuracy_score(y_test, y_pred, average="micro")
  precision = precision_score(y_test, y_pred, average="micro")
  matrix = confusion_matrix(y_test, y_pred, average="micro")
  report = classification_report(y_test, y_pred, average="micro")
  auc = roc_auc_score(y_test, model.predict_proba(X_test)[::,1], average="micro")

  print("Accuracy: {}".format(accuracy))
  print("Precission {}".format(precision))
  # print("Confusion matrix: {}".format(matrix))
  print("Report: {}".format(report))
  print("AUC: {}".format(auc))
  print("Cross: {}".format(cross_val_score(model, X_test, y_test, cv=5).mean()))

# %%
def validation(model, X_train, y_train, X_test, y_test, X_valid=None, y_valid=None):
  scores = [(X_train, y_train), (X_test, y_test), (X_valid, y_valid)]
  data = []
  for score in scores:
    y_pred = model.predict(score[0])

    accuracy = accuracy_score(score[1], y_pred)
    precision = precision_score(score[1], y_pred)
    recall = recall_score(score[1], y_pred)
    matrix = confusion_matrix(score[1], y_pred)
    report = classification_report(score[1], y_pred)
    auc = roc_auc_score(score[1], model.predict_proba(score[0])[::,1])
    cross = cross_val_score(model, score[0], score[1], cv=5).mean()
    
    data.append([accuracy, precision, recall, auc, cross])

    """ print("Accuracy: {}".format(accuracy))
    print("Precission {}".format(precision))
    # print("Confusion matrix: {}".format(matrix))
    print("Report: {}".format(report))
    print("AUC: {}".format(auc))
    print("Cross: {}".format(cross) """

  df = pd.DataFrame(data, columns=["Accuracy", "Precision", "Recall", "AUC", "Cross"],
                    index =["Train", "Test", "Valid"])
  return df

# %%
def validation_multi(model, X_train, y_train, X_test, y_test): # , X_valid=None, y_valid=None):
  scores = [(X_train, y_train), (X_test, y_test)] # , (X_valid, y_valid)]
  data = []
  for score in scores:
    y_pred = model.predict(score[0])

    accuracy = accuracy_score(score[1], y_pred)
    precision = precision_score(score[1], y_pred, average="micro")
    recall = recall_score(score[1], y_pred, average="micro")
    matrix = confusion_matrix(score[1], y_pred)
    report = classification_report(score[1], y_pred)
    auc = roc_auc_score(score[1], model.predict_proba(score[0]), multi_class="ovr")
    cross = cross_val_score(model, score[0], score[1], cv=5).mean()
    
    data.append([accuracy, precision, recall, auc, cross])

  df = pd.DataFrame(data, columns=["Accuracy", "Precision", "Recall", "AUC", "Cross"],
                    index =["Train", "Test"]) # , "Valid"])
  return df
# Out:
# time: 2.55 ms (started: 2022-06-26 18:40:54 -05:00)

# %%
def get_metrics(df):
  df = df.to_dict(orient="split")
  metrics = {}
  for i, index in enumerate(df["index"]):
    for j, column in enumerate(df["columns"]):
      metrics["{}_{}".format(index, column)] = df["data"][i][j]
  return metrics

# %% [markdown]
# ####custom_dropcol_importance

# %%
# Implementation modified from https://github.com/parrt/random-forest-importances/blob/master/src/rfpimp.py#L292

def custom_dropcol_importance(random_forest, x, y):
  random_forest_ = clone(random_forest)
  random_forest_.random_state = 999
  random_forest_.fit(x, y)
  baseline = random_forest_.oob_score_
  importances = []
  for col in x.columns:
      x_without_column = x.drop(col, axis=1)
      random_forest_ = clone(random_forest)
      random_forest_.random_state = 999
      random_forest_.fit(x_without_column, y)
      o = random_forest_.oob_score_
      importances.append(baseline - o)
  importances = np.array(importances)
  
  I = pd.DataFrame(data={"columns": x.columns, "importances": importances})
  I = I.sort_values("importances", ascending=True)

  return I

# %% [markdown]
# ### **Load Dataset**

# %%
try:
  from google.colab import drive
  drive.mount("/content/drive")
except:
  pass

# %%
if LOCAL:
  dir = "/home/laad/Projects/IA/ClassifierCodon/Project2"
else:
  dir = "/content/drive/MyDrive/PUCP/Phd/S1/A.A./Projects/Project2"

# %%
df = pd.read_csv("{}/codon_usage.csv".format(dir))

print(df.shape)
df.tail()
# Out:
# (13028, 69)
# /tmp/ipykernel_197294/3902934774.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("{}/codon_usage.csv".format(dir))
#       Kingdom  DNAtype  SpeciesID   Ncodons  \
# 13023     pri        0       9601      1097
# 13024     pri        1       9601      2067
# 13025     pri        1       9602      1686
# 13026     pri        0       9606  40662582
# 13027     pri        1       9606   8998998
#
#                                  SpeciesName      UUU      UUC      UUA  \
# 13023                  Pongo pygmaeus abelii  0.02552  0.03555  0.00547
# 13024    mitochondrion Pongo pygmaeus abelii  0.01258  0.03193  0.01984
# 13025  mitochondrion Pongo pygmaeus pygmaeus  0.01423  0.03321  0.01661
# 13026                           Homo sapiens  0.01757  0.02028  0.00767
# 13027             mitochondrion Homo sapiens  0.01778  0.03724  0.01732
#
#            UUG      CUU  ...      CGG      AGA      AGG      GAU      GAC  \
# 13023  0.01367  0.01276  ...  0.00820  0.01367  0.01094  0.01367  0.02279
# 13024  0.00629  0.01451  ...  0.00145  0.00000  0.00048  0.00194  0.01306
# 13025  0.00356  0.01127  ...  0.00000  0.00000  0.00000  0.00178  0.01661
# 13026  0.01293  0.01319  ...  0.01142  0.01217  0.01196  0.02178  0.02510
# 13027  0.00600  0.01689  ...  0.00083  0.00041  0.00041  0.00451  0.01402
#
#            GAA      GAG      UAA      UAG      UGA
# 13023  0.02005  0.04102  0.00091  0.00091  0.00638
# 13024  0.01838  0.00677  0.00242  0.00097  0.01887
# 13025  0.02788  0.00297  0.00356  0.00119  0.02017
# 13026  0.02896  0.03959  0.00099  0.00079  0.00156
# 13027  0.01651  0.00783  0.00156  0.00114  0.02161
#
# [5 rows x 69 columns]

# %%
df.dtypes
# Out:
# Kingdom         object
# DNAtype          int64
# SpeciesID        int64
# Ncodons          int64
# SpeciesName     object
#                 ...
# GAA            float64
# GAG            float64
# UAA            float64
# UAG            float64
# UGA            float64
# Length: 69, dtype: object

# %%
df.describe()
# Out:
#             DNAtype      SpeciesID       Ncodons           UUA           UUG  \
# count  13028.000000   13028.000000  1.302800e+04  13028.000000  13028.000000
# mean       0.367209  130451.105926  7.960576e+04      0.020637      0.014104
# std        0.688726  124787.086107  7.197010e+05      0.020709      0.009280
# min        0.000000       7.000000  1.000000e+03      0.000000      0.000000
# 25%        0.000000   28850.750000  1.602000e+03      0.005610      0.007108
# 50%        0.000000   81971.500000  2.927500e+03      0.015260      0.013360
# 75%        1.000000  222891.250000  9.120000e+03      0.029485      0.019810
# max       12.000000  465364.000000  4.066258e+07      0.151330      0.101190
#
#                 CUU           CUC           CUA           CUG           AUU  \
# count  13028.000000  13028.000000  13028.000000  13028.000000  13028.000000
# mean       0.017820      0.018288      0.019044      0.018450      0.028352
# std        0.010586      0.014572      0.024250      0.016578      0.017507
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.010890      0.007830      0.005307      0.007180      0.016360
# 50%        0.016130      0.014560      0.009685      0.012800      0.025475
# 75%        0.022730      0.025112      0.017245      0.024315      0.038113
# max        0.089780      0.100350      0.163920      0.107370      0.154060
#
#        ...           CGG           AGA           AGG           GAU  \
# count  ...  13028.000000  13028.000000  13028.000000  13028.000000
# mean   ...      0.005454      0.009929      0.006422      0.024178
# std    ...      0.006605      0.008574      0.006387      0.013828
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.001220      0.001690      0.001170      0.012380
# 50%    ...      0.003530      0.009270      0.004545      0.025420
# 75%    ...      0.007150      0.015922      0.010250      0.034190
# max    ...      0.055540      0.098830      0.058430      0.185660
#
#                 GAC           GAA           GAG           UAA           UAG  \
# count  13028.000000  13028.000000  13028.000000  13028.000000  13028.000000
# mean       0.021164      0.028290      0.021683      0.001645      0.000592
# std        0.013041      0.014342      0.015018      0.001834      0.000907
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.011860      0.017360      0.009710      0.000560      0.000000
# 50%        0.019070      0.026085      0.020540      0.001380      0.000420
# 75%        0.027690      0.036800      0.031122      0.002370      0.000830
# max        0.113840      0.144890      0.158550      0.045200      0.025610
#
#                 UGA
# count  13028.000000
# mean       0.006178
# std        0.010344
# min        0.000000
# 25%        0.000410
# 50%        0.001130
# 75%        0.002890
# max        0.106700
#
# [8 rows x 65 columns]

# %%
print(df.shape)
preview_dataset(df)
# Out:
# (13028, 69)
# Column name: Kingdom
# bct    2920
# vrl    2832
# pln    2523
# vrt    2077
# inv    1345
# mam     572
# phg     220
# rod     215
# pri     180
# arc     126
# plm      18
# Name: Kingdom, dtype: int64
#
# Column name: SpeciesName
# Escherichia coli O157                         4
# Escherichia coli O111                         3
# Ageratum yellow vein Hualian virus-[Taiwan    3
# Cotton leaf curl Rajasthan virus - [India     3
# Tomato leaf curl Bangalore virus - [India     2
#                                              ..
# Gordonia sp. TY-5                             1
# Pseudomonas sp. PCL1171                       1
# Geobacillus kaustophilus HTA426               1
# Brucella ovis                                 1
# mitochondrion Homo sapiens                    1
# Name: SpeciesName, Length: 13016, dtype: int64
#
# Column name: UUU
# 0          69
# 0.04536    34
# 0.04618    28
# 0.01423    14
# 0.00576    13
#            ..
# 0.01127     1
# 0.03082     1
# 0.02905     1
# 0.01013     1
# 0.01778     1
# Name: UUU, Length: 6797, dtype: int64
#
# Column name: UUC
# 0.02564    42
# 0.01911    40
# 0.01134    16
# 0.01146    15
# 0.03458    14
#            ..
# 0.02183     1
# 0.04646     1
# 0.02947     1
# 0.03528     1
# 0.03555     1
# Name: UUC, Length: 5874, dtype: int64
#
# Column name: DNAtype
# NANs: 0
# Negatives: 0
# Zeros: 9267
# Positives: 3761
#
# 0     9267
# 1     2899
# 2      816
# 4       31
# 12       5
# 3        2
# 9        2
# 5        2
# 11       2
# 6        1
# 7        1
# Name: DNAtype, dtype: int64
# Column name: SpeciesID
# NANs: 0
# Negatives: 0
# Zeros: 0
# Positives: 13028
#
# 3885      4
# 3702      4
# 4565      4
# 2771      4
# 4577      4
#          ..
# 2021      1
# 2026      1
# 202751    1
# 202752    1
# 114524    1
# Name: SpeciesID, Length: 12368, dtype: int64
# Column name: Ncodons
# NANs: 0
# Negatives: 0
# Zeros: 0
# Positives: 13028
#
# 1140       67
# 1784       58
# 1054       44
# 1014       39
# 1047       39
#            ..
# 8238        1
# 351818      1
# 2622925     1
# 572059      1
# 8998998     1
# Name: Ncodons, Length: 7103, dtype: int64
# Column name: UUA
# NANs: 0
# Negatives: 0
# Zeros: 460
# Positives: 12568
#
# 0.00000    460
# 0.01513     41
# 0.03748     32
# 0.00093     17
# 0.01682     15
#           ...
# 0.06606      1
# 0.06425      1
# 0.01548      1
# 0.08363      1
# 0.04059      1
# Name: UUA, Length: 4796, dtype: int64
# Column name: UUG
# NANs: 0
# Negatives: 0
# Zeros: 452
# Positives: 12576
#
# 0.00000    452
# 0.00263     47
# 0.01035     42
# 0.03156     34
# 0.01774     23
#           ...
# 0.02372      1
# 0.03017      1
# 0.03006      1
# 0.02743      1
# 0.00619      1
# Name: UUG, Length: 3282, dtype: int64
# Column name: CUU
# NANs: 0
# Negatives: 0
# Zeros: 35
# Positives: 12993
#
# 0.02564    43
# 0.02627    35
# 0.00000    35
# 0.01312    22
# 0.01316    19
#            ..
# 0.02680     1
# 0.05143     1
# 0.03224     1
# 0.00668     1
# 0.03415     1
# Name: CUU, Length: 3677, dtype: int64
# Column name: CUC
# NANs: 0
# Negatives: 0
# Zeros: 241
# Positives: 12787
#
# 0.00000    241
# 0.00789     40
# 0.01513     38
# 0.00195     26
# 0.00587     20
#           ...
# 0.04569      1
# 0.02333      1
# 0.01157      1
# 0.05463      1
# 0.05042      1
# Name: CUC, Length: 4389, dtype: int64
# Column name: CUA
# NANs: 0
# Negatives: 0
# Zeros: 275
# Positives: 12753
#
# 0.00000    275
# 0.00796     39
# 0.01775     31
# 0.01389     24
# 0.00907     22
#           ...
# 0.06628      1
# 0.04931      1
# 0.05101      1
# 0.05810      1
# 0.07604      1
# Name: CUA, Length: 4063, dtype: int64
# Column name: CUG
# NANs: 0
# Negatives: 0
# Zeros: 223
# Positives: 12805
#
# 0.00000    223
# 0.00789     56
# 0.00318     43
# 0.00263     30
# 0.00975     25
#           ...
# 0.06188      1
# 0.03148      1
# 0.04347      1
# 0.04005      1
# 0.03555      1
# Name: CUG, Length: 4562, dtype: int64
# Column name: AUU
# NANs: 0
# Negatives: 0
# Zeros: 51
# Positives: 12977
#
# 0.00000    51
# 0.04734    38
# 0.04220    28
# 0.02170    15
# 0.02092    13
#            ..
# 0.00947     1
# 0.05244     1
# 0.00486     1
# 0.00346     1
# 0.02772     1
# Name: AUU, Length: 5243, dtype: int64
# Column name: AUC
# NANs: 0
# Negatives: 0
# Zeros: 15
# Positives: 13013
#
# 0.00986    47
# 0.00796    29
# 0.00992    18
# 0.01124    17
# 0.01701    16
#            ..
# 0.01244     1
# 0.03966     1
# 0.04367     1
# 0.01103     1
# 0.05137     1
# Name: AUC, Length: 4684, dtype: int64
# Column name: AUA
# NANs: 0
# Negatives: 0
# Zeros: 289
# Positives: 12739
#
# 0.00000    289
# 0.01775     40
# 0.01115     39
# 0.02579     29
# 0.02362     18
#           ...
# 0.03418      1
# 0.02831      1
# 0.03391      1
# 0.02253      1
# 0.03435      1
# Name: AUA, Length: 4477, dtype: int64
# Column name: AUG
# NANs: 0
# Negatives: 0
# Zeros: 13
# Positives: 13015
#
# 0.00263    46
# 0.01775    38
# 0.00789    36
# 0.01592    35
# 0.00526    27
#            ..
# 0.03429     1
# 0.04674     1
# 0.01220     1
# 0.03785     1
# 0.00582     1
# Name: AUG, Length: 3237, dtype: int64
# Column name: GUU
# NANs: 0
# Negatives: 0
# Zeros: 106
# Positives: 12922
#
# 0.00000    106
# 0.01183     43
# 0.03901     26
# 0.00860     25
# 0.00525     24
#           ...
# 0.00410      1
# 0.03243      1
# 0.03013      1
# 0.03568      1
# 0.00629      1
# Name: GUU, Length: 3640, dtype: int64
# Column name: GUC
# NANs: 0
# Negatives: 0
# Zeros: 94
# Positives: 12934
#
# 0.00000    94
# 0.00592    51
# 0.01513    49
# 0.01316    30
# 0.00287    22
#            ..
# 0.02857     1
# 0.02771     1
# 0.04375     1
# 0.05258     1
# 0.00498     1
# Name: GUC, Length: 3602, dtype: int64
# Column name: GUA
# NANs: 0
# Negatives: 0
# Zeros: 111
# Positives: 12917
#
# 0.00000    111
# 0.01775     44
# 0.00955     40
# 0.00287     26
# 0.00573     22
#           ...
# 0.03025      1
# 0.03952      1
# 0.02827      1
# 0.02954      1
# 0.03358      1
# Name: GUA, Length: 3149, dtype: int64
# Column name: GUG
# NANs: 0
# Negatives: 0
# Zeros: 418
# Positives: 12610
#
# 0.00000    418
# 0.00263     54
# 0.00592     45
# 0.01035     36
# 0.00262     25
#           ...
# 0.02491      1
# 0.04024      1
# 0.03010      1
# 0.02562      1
# 0.04154      1
# Name: GUG, Length: 3993, dtype: int64
# Column name: GCU
# NANs: 0
# Negatives: 0
# Zeros: 21
# Positives: 13007
#
# 0.01972    36
# 0.03742    27
# 0.01316    23
# 0.01053    22
# 0.00000    21
#            ..
# 0.00416     1
# 0.04273     1
# 0.00255     1
# 0.03596     1
# 0.01109     1
# Name: GCU, Length: 3725, dtype: int64
# Column name: GCC
# NANs: 0
# Negatives: 0
# Zeros: 86
# Positives: 12942
#
# 0.00000    86
# 0.00789    43
# 0.00955    37
# 0.02105    25
# 0.00198    23
#            ..
# 0.05843     1
# 0.04650     1
# 0.01482     1
# 0.08953     1
# 0.03821     1
# Name: GCC, Length: 5044, dtype: int64
# Column name: GCA
# NANs: 0
# Negatives: 0
# Zeros: 25
# Positives: 13003
#
# 0.00789    41
# 0.01354    32
# 0.00000    25
# 0.02632    24
# 0.02292    22
#            ..
# 0.01119     1
# 0.00701     1
# 0.00051     1
# 0.01241     1
# 0.00576     1
# Name: GCA, Length: 3451, dtype: int64
# Column name: GCG
# NANs: 0
# Negatives: 0
# Zeros: 831
# Positives: 12197
#
# 0.00000    831
# 0.00197     73
# 0.00398     45
# 0.00196     42
# 0.00198     37
#           ...
# 0.04474      1
# 0.04151      1
# 0.03235      1
# 0.03905      1
# 0.01990      1
# Name: GCG, Length: 3559, dtype: int64
# Column name: CCU
# NANs: 0
# Negatives: 0
# Zeros: 53
# Positives: 12975
#
# 0.00000    53
# 0.01183    33
# 0.02707    29
# 0.00984    25
# 0.00789    24
#            ..
# 0.02829     1
# 0.02818     1
# 0.06183     1
# 0.00138     1
# 0.02931     1
# Name: CCU, Length: 2751, dtype: int64
# Column name: CCC
# NANs: 0
# Negatives: 0
# Zeros: 204
# Positives: 12824
#
# 0.00000    204
# 0.00239     43
# 0.00787     28
# 0.01316     23
# 0.00403     22
#           ...
# 0.03733      1
# 0.04898      1
# 0.03044      1
# 0.01634      1
# 0.01979      1
# Name: CCC, Length: 3221, dtype: int64
# Column name: CCA
# NANs: 0
# Negatives: 0
# Zeros: 69
# Positives: 12959
#
# 0.00000    69
# 0.01381    47
# 0.01513    43
# 0.00860    35
# 0.01389    22
#            ..
# 0.02946     1
# 0.02301     1
# 0.02200     1
# 0.00125     1
# 0.03191     1
# Name: CCA, Length: 3488, dtype: int64
# Column name: CCG
# NANs: 0
# Negatives: 0
# Zeros: 753
# Positives: 12275
#
# 0.00000    753
# 0.00263     53
# 0.00159     52
# 0.00394     36
# 0.00195     35
#           ...
# 0.03504      1
# 0.02262      1
# 0.03157      1
# 0.01463      1
# 0.01332      1
# Name: CCG, Length: 2889, dtype: int64
# Column name: UGG
# NANs: 0
# Negatives: 0
# Zeros: 406
# Positives: 12622
#
# 0.00000    406
# 0.01578     46
# 0.00263     44
# 0.00876     44
# 0.01389     28
#           ...
# 0.02351      1
# 0.02395      1
# 0.03401      1
# 0.00743      1
# 0.00433      1
# Name: UGG, Length: 2597, dtype: int64
# Column name: GGU
# NANs: 0
# Negatives: 0
# Zeros: 134
# Positives: 12894
#
# 0.00000    134
# 0.00789     67
# 0.02468     35
# 0.00526     30
# 0.00787     23
#           ...
# 0.04344      1
# 0.05880      1
# 0.03922      1
# 0.04768      1
# 0.00237      1
# Name: GGU, Length: 3622, dtype: int64
# Column name: GGC
# NANs: 0
# Negatives: 0
# Zeros: 176
# Positives: 12852
#
# 0.00000    176
# 0.00592     38
# 0.00197     37
# 0.00198     32
# 0.01911     28
#           ...
# 0.04846      1
# 0.05385      1
# 0.05030      1
# 0.04991      1
# 0.02163      1
# Name: GGC, Length: 4392, dtype: int64
# Column name: GGA
# NANs: 0
# Negatives: 0
# Zeros: 34
# Positives: 12994
#
# 0.01592    48
# 0.01183    42
# 0.00000    34
# 0.01992    20
# 0.02092    19
#            ..
# 0.03009     1
# 0.03641     1
# 0.03859     1
# 0.04386     1
# 0.00503     1
# Name: GGA, Length: 3538, dtype: int64
# Column name: GGG
# NANs: 0
# Negatives: 0
# Zeros: 201
# Positives: 12827
#
# 0.00000    201
# 0.01183     42
# 0.00263     42
# 0.00318     40
# 0.00789     35
#           ...
# 0.02668      1
# 0.03329      1
# 0.02682      1
# 0.00829      1
# 0.02129      1
# Name: GGG, Length: 2613, dtype: int64
# Column name: UCU
# NANs: 0
# Negatives: 0
# Zeros: 131
# Positives: 12897
#
# 0.00000    131
# 0.00526     27
# 0.00573     25
# 0.00860     24
# 0.04734     23
#           ...
# 0.04403      1
# 0.04599      1
# 0.04590      1
# 0.02064      1
# 0.00626      1
# Name: UCU, Length: 3273, dtype: int64
# Column name: UCC
# NANs: 0
# Negatives: 0
# Zeros: 104
# Positives: 12924
#
# 0.00000    104
# 0.01972     36
# 0.00478     33
# 0.01579     22
# 0.01316     21
#           ...
# 0.03573      1
# 0.02828      1
# 0.03704      1
# 0.02214      1
# 0.02995      1
# Name: UCC, Length: 2997, dtype: int64
# Column name: UCA
# NANs: 0
# Negatives: 0
# Zeros: 103
# Positives: 12925
#
# 0.00000    103
# 0.02761     39
# 0.02309     29
# 0.02105     22
# 0.01587     21
#           ...
# 0.04307      1
# 0.03622      1
# 0.03233      1
# 0.02077      1
# 0.02371      1
# Name: UCA, Length: 3391, dtype: int64
# Column name: UCG
# NANs: 0
# Negatives: 0
# Zeros: 816
# Positives: 12212
#
# 0.00000    816
# 0.00287     42
# 0.00239     39
# 0.00263     36
# 0.01183     36
#           ...
# 0.02282      1
# 0.02093      1
# 0.01455      1
# 0.02346      1
# 0.00009      1
# Name: UCG, Length: 2306, dtype: int64
# Column name: AGU
# NANs: 0
# Negatives: 0
# Zeros: 591
# Positives: 12437
#
# 0.00000    591
# 0.00263     70
# 0.01381     44
# 0.00336     33
# 0.00955     31
#           ...
# 0.02328      1
# 0.02397      1
# 0.02028      1
# 0.00534      1
# 0.02090      1
# Name: AGU, Length: 2440, dtype: int64
# Column name: AGC
# NANs: 0
# Negatives: 0
# Zeros: 196
# Positives: 12832
#
# 0.00000    196
# 0.00262     52
# 0.00394     50
# 0.00789     45
# 0.00478     44
#           ...
# 0.04033      1
# 0.00236      1
# 0.00110      1
# 0.02107      1
# 0.01958      1
# Name: AGC, Length: 2565, dtype: int64
# Column name: ACU
# NANs: 0
# Negatives: 0
# Zeros: 70
# Positives: 12958
#
# 0.00000    70
# 0.01183    43
# 0.03662    29
# 0.00789    25
# 0.01053    24
#            ..
# 0.03822     1
# 0.04207     1
# 0.02945     1
# 0.00209     1
# 0.03280     1
# Name: ACU, Length: 3253, dtype: int64
# Column name: ACC
# NANs: 0
# Negatives: 0
# Zeros: 71
# Positives: 12957
#
# 0.00000    71
# 0.00197    47
# 0.00955    38
# 0.00196    30
# 0.00789    20
#            ..
# 0.04052     1
# 0.04166     1
# 0.05027     1
# 0.04311     1
# 0.05031     1
# Name: ACC, Length: 4188, dtype: int64
# Column name: ACA
# NANs: 0
# Negatives: 0
# Zeros: 100
# Positives: 12928
#
# 0.00000    100
# 0.00197     43
# 0.02866     25
# 0.00196     22
# 0.01481     17
#           ...
# 0.03799      1
# 0.05570      1
# 0.04764      1
# 0.03894      1
# 0.03446      1
# Name: ACA, Length: 4170, dtype: int64
# Column name: ACG
# NANs: 0
# Negatives: 0
# Zeros: 646
# Positives: 12382
#
# 0.00000    646
# 0.00394     58
# 0.00263     45
# 0.00318     43
# 0.00198     37
#           ...
# 0.01378      1
# 0.03322      1
# 0.03668      1
# 0.01942      1
# 0.00013      1
# Name: ACG, Length: 2484, dtype: int64
# Column name: UAU
# NANs: 0
# Negatives: 0
# Zeros: 122
# Positives: 12906
#
# 0.00000    122
# 0.04536     31
# 0.00573     26
# 0.02787     25
# 0.00576     24
#           ...
# 0.00941      1
# 0.03430      1
# 0.00449      1
# 0.03611      1
# 0.00994      1
# Name: UAU, Length: 3977, dtype: int64
# Column name: UAC
# NANs: 0
# Negatives: 0
# Zeros: 36
# Positives: 12992
#
# 0.01433    53
# 0.00986    44
# 0.00000    36
# 0.01441    27
# 0.01719    25
#            ..
# 0.04339     1
# 0.03076     1
# 0.03410     1
# 0.00612     1
# 0.02223     1
# Name: UAC, Length: 3003, dtype: int64
# Column name: CAA
# NANs: 0
# Negatives: 0
# Zeros: 54
# Positives: 12974
#
# 0.01579    63
# 0.00000    54
# 0.02367    46
# 0.03503    36
# 0.01842    34
#            ..
# 0.00982     1
# 0.03634     1
# 0.03823     1
# 0.01012     1
# 0.05165     1
# Name: CAA, Length: 3670, dtype: int64
# Column name: CAG
# NANs: 0
# Negatives: 0
# Zeros: 452
# Positives: 12576
#
# 0.00000    452
# 0.00789     46
# 0.00263     39
# 0.00262     36
# 0.00287     25
#           ...
# 0.07205      1
# 0.06577      1
# 0.04276      1
# 0.07699      1
# 0.03423      1
# Name: CAG, Length: 3724, dtype: int64
# Column name: AAU
# NANs: 0
# Negatives: 0
# Zeros: 60
# Positives: 12968
#
# 0.00000    60
# 0.04536    38
# 0.00860    20
# 0.04140    20
# 0.00789    19
#            ..
# 0.00160     1
# 0.05670     1
# 0.03411     1
# 0.05444     1
# 0.01351     1
# Name: AAU, Length: 4661, dtype: int64
# Column name: AAC
# NANs: 0
# Negatives: 0
# Zeros: 24
# Positives: 13004
#
# 0.00986    40
# 0.02229    35
# 0.00000    24
# 0.01433    20
# 0.02632    20
#            ..
# 0.00553     1
# 0.00538     1
# 0.00526     1
# 0.03651     1
# 0.03683     1
# Name: AAC, Length: 3675, dtype: int64
# Column name: UGU
# NANs: 0
# Negatives: 0
# Zeros: 839
# Positives: 12189
#
# 0.00000    839
# 0.00263     76
# 0.00986     52
# 0.00336     32
# 0.00264     31
#           ...
# 0.01925      1
# 0.02870      1
# 0.02368      1
# 0.02979      1
# 0.01779      1
# Name: UGU, Length: 2205, dtype: int64
# Column name: UGC
# NANs: 0
# Negatives: 0
# Zeros: 508
# Positives: 12520
#
# 0.00000    508
# 0.00287     59
# 0.00789     53
# 0.01053     50
# 0.00787     39
#           ...
# 0.01945      1
# 0.01289      1
# 0.01534      1
# 0.01595      1
# 0.02461      1
# Name: UGC, Length: 2196, dtype: int64
# Column name: CAU
# NANs: 0
# Negatives: 0
# Zeros: 147
# Positives: 12881
#
# 0.00000    147
# 0.01035     43
# 0.00860     38
# 0.01053     35
# 0.01316     33
#           ...
# 0.00158      1
# 0.01853      1
# 0.02815      1
# 0.02254      1
# 0.02540      1
# Name: CAU, Length: 2615, dtype: int64
# Column name: CAC
# NANs: 0
# Negatives: 0
# Zeros: 88
# Positives: 12940
#
# 0.00000    88
# 0.00789    47
# 0.00159    37
# 0.01433    23
# 0.01146    22
#            ..
# 0.04634     1
# 0.02309     1
# 0.00137     1
# 0.02746     1
# 0.01802     1
# Name: CAC, Length: 2668, dtype: int64
# Column name: AAA
# NANs: 0
# Negatives: 0
# Zeros: 57
# Positives: 12971
#
# 0.00000    57
# 0.02368    41
# 0.02362    37
# 0.04339    35
# 0.02632    28
#            ..
# 0.00531     1
# 0.00160     1
# 0.07862     1
# 0.09140     1
# 0.02359     1
# Name: AAA, Length: 5288, dtype: int64
# Column name: AAG
# NANs: 0
# Negatives: 0
# Zeros: 405
# Positives: 12623
#
# 0.00000    405
# 0.00263     65
# 0.01972     36
# 0.02070     32
# 0.00262     32
#           ...
# 0.07888      1
# 0.04640      1
# 0.04030      1
# 0.04540      1
# 0.04366      1
# Name: AAG, Length: 4532, dtype: int64
# Column name: CGU
# NANs: 0
# Negatives: 0
# Zeros: 579
# Positives: 12449
#
# 0.00000    579
# 0.00263     86
# 0.00287     68
# 0.00557     43
# 0.00262     36
#           ...
# 0.01690      1
# 0.01899      1
# 0.02433      1
# 0.02224      1
# 0.00039      1
# Name: CGU, Length: 2298, dtype: int64
# Column name: CGC
# NANs: 0
# Negatives: 0
# Zeros: 506
# Positives: 12522
#
# 0.00000    506
# 0.00526     72
# 0.00263     54
# 0.00592     54
# 0.00288     48
#           ...
# 0.03565      1
# 0.05390      1
# 0.03538      1
# 0.02721      1
# 0.02094      1
# Name: CGC, Length: 3182, dtype: int64
# Column name: CGA
# NANs: 0
# Negatives: 0
# Zeros: 337
# Positives: 12691
#
# 0.00000    337
# 0.01316     50
# 0.01579     49
# 0.00318     43
# 0.00576     38
#           ...
# 0.02185      1
# 0.01818      1
# 0.02170      1
# 0.01881      1
# 0.01248      1
# Name: CGA, Length: 1880, dtype: int64
# Column name: CGG
# NANs: 0
# Negatives: 0
# Zeros: 1399
# Positives: 11629
#
# 0.00000    1399
# 0.00394      57
# 0.00159      43
# 0.00263      43
# 0.00057      39
#            ...
# 0.01944       1
# 0.01939       1
# 0.03009       1
# 0.01278       1
# 0.01037       1
# Name: CGG, Length: 2136, dtype: int64
# Column name: AGA
# NANs: 0
# Negatives: 0
# Zeros: 1772
# Positives: 11256
#
# 0.00000    1772
# 0.00263     161
# 0.02170      37
# 0.00034      31
# 0.00264      28
#            ...
# 0.03982       1
# 0.02182       1
# 0.04169       1
# 0.00480       1
# 0.00846       1
# Name: AGA, Length: 2835, dtype: int64
# Column name: AGG
# NANs: 0
# Negatives: 0
# Zeros: 2230
# Positives: 10798
#
# 0.00000    2230
# 0.00986      43
# 0.00391      37
# 0.00056      36
# 0.00198      34
#            ...
# 0.01745       1
# 0.01993       1
# 0.02074       1
# 0.01471       1
# 0.01333       1
# Name: AGG, Length: 2228, dtype: int64
# Column name: GAU
# NANs: 0
# Negatives: 0
# Zeros: 261
# Positives: 12767
#
# 0.00000    261
# 0.02367     41
# 0.03901     31
# 0.00526     29
# 0.00789     28
#           ...
# 0.04612      1
# 0.04658      1
# 0.04981      1
# 0.01680      1
# 0.00451      1
# Name: GAU, Length: 4578, dtype: int64
# Column name: GAC
# NANs: 0
# Negatives: 0
# Zeros: 114
# Positives: 12914
#
# 0.00000    114
# 0.00789     45
# 0.00287     37
# 0.01842     32
# 0.01911     29
#           ...
# 0.00695      1
# 0.05964      1
# 0.00776      1
# 0.05169      1
# 0.03401      1
# Name: GAC, Length: 4416, dtype: int64
# Column name: GAA
# NANs: 0
# Negatives: 0
# Zeros: 16
# Positives: 13012
#
# 0.01316    55
# 0.01579    52
# 0.01433    41
# 0.03353    35
# 0.01837    27
#            ..
# 0.05991     1
# 0.04862     1
# 0.04214     1
# 0.04971     1
# 0.00744     1
# Name: GAA, Length: 4827, dtype: int64
# Column name: GAG
# NANs: 0
# Negatives: 0
# Zeros: 438
# Positives: 12590
#
# 0.00000    438
# 0.00263     45
# 0.01381     36
# 0.01672     33
# 0.00287     20
#           ...
# 0.06047      1
# 0.00832      1
# 0.01108      1
# 0.08218      1
# 0.03689      1
# Name: GAG, Length: 4686, dtype: int64
# Column name: UAA
# NANs: 0
# Negatives: 0
# Zeros: 1812
# Positives: 11216
#
# 0.00000    1812
# 0.00046     122
# 0.00287      97
# 0.00262      92
# 0.00080      84
#            ...
# 0.00645       1
# 0.02411       1
# 0.00332       1
# 0.03484       1
# 0.00860       1
# Name: UAA, Length: 703, dtype: int64
# Column name: UAG
# NANs: 0
# Negatives: 0
# Zeros: 4329
# Positives: 8699
#
# 0.00000    4329
# 0.00090     123
# 0.00056     119
# 0.00044     113
# 0.00047     110
#            ...
# 0.00831       1
# 0.00407       1
# 0.00396       1
# 0.00347       1
# 0.00321       1
# Name: UAG, Length: 422, dtype: int64
# Column name: UGA
# NANs: 0
# Negatives: 0
# Zeros: 2145
# Positives: 10883
#
# 0.00000    2145
# 0.00197      98
# 0.00090      80
# 0.00196      71
# 0.00091      70
#            ...
# 0.01336       1
# 0.01138       1
# 0.02055       1
# 0.00887       1
# 0.00638       1
# Name: UGA, Length: 1786, dtype: int64

# %%
df.columns
# Out:
# Index(['Kingdom', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName', 'UUU',
#        'UUC', 'UUA', 'UUG', 'CUU', 'CUC', 'CUA', 'CUG', 'AUU', 'AUC', 'AUA',
#        'AUG', 'GUU', 'GUC', 'GUA', 'GUG', 'GCU', 'GCC', 'GCA', 'GCG', 'CCU',
#        'CCC', 'CCA', 'CCG', 'UGG', 'GGU', 'GGC', 'GGA', 'GGG', 'UCU', 'UCC',
#        'UCA', 'UCG', 'AGU', 'AGC', 'ACU', 'ACC', 'ACA', 'ACG', 'UAU', 'UAC',
#        'CAA', 'CAG', 'AAU', 'AAC', 'UGU', 'UGC', 'CAU', 'CAC', 'AAA', 'AAG',
#        'CGU', 'CGC', 'CGA', 'CGG', 'AGA', 'AGG', 'GAU', 'GAC', 'GAA', 'GAG',
#        'UAA', 'UAG', 'UGA'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Kingdom         object
# DNAtype          int64
# SpeciesID        int64
# Ncodons          int64
# SpeciesName     object
#                 ...
# GAA            float64
# GAG            float64
# UAA            float64
# UAG            float64
# UGA            float64
# Length: 69, dtype: object

# %%
df[["DNAtype", "SpeciesID", "Ncodons", "CUC"]].hist(figsize=(12, 12))
# Out:
# array([[<AxesSubplot:title={'center':'DNAtype'}>,
#         <AxesSubplot:title={'center':'SpeciesID'}>],
#        [<AxesSubplot:title={'center':'Ncodons'}>,
#         <AxesSubplot:title={'center':'CUC'}>]], dtype=object)

# %%
df
# Out:
#       Kingdom  DNAtype  SpeciesID   Ncodons  \
# 0         vrl        0     100217      1995
# 1         vrl        0     100220      1474
# 2         vrl        0     100755      4862
# 3         vrl        0     100880      1915
# 4         vrl        0     100887     22831
# ...       ...      ...        ...       ...
# 13023     pri        0       9601      1097
# 13024     pri        1       9601      2067
# 13025     pri        1       9602      1686
# 13026     pri        0       9606  40662582
# 13027     pri        1       9606   8998998
#
#                                    SpeciesName      UUU      UUC      UUA  \
# 0      Epizootic haematopoietic necrosis virus  0.01654  0.01203  0.00050
# 1                             Bohle iridovirus  0.02714  0.01357  0.00068
# 2                 Sweet potato leaf curl virus  0.01974   0.0218  0.01357
# 3                 Northern cereal mosaic virus  0.01775  0.02245  0.01619
# 4               Soil-borne cereal mosaic virus  0.02816  0.01371  0.00767
# ...                                        ...      ...      ...      ...
# 13023                    Pongo pygmaeus abelii  0.02552  0.03555  0.00547
# 13024      mitochondrion Pongo pygmaeus abelii  0.01258  0.03193  0.01984
# 13025    mitochondrion Pongo pygmaeus pygmaeus  0.01423  0.03321  0.01661
# 13026                             Homo sapiens  0.01757  0.02028  0.00767
# 13027               mitochondrion Homo sapiens  0.01778  0.03724  0.01732
#
#            UUG      CUU  ...      CGG      AGA      AGG      GAU      GAC  \
# 0      0.00351  0.01203  ...  0.00451  0.01303  0.03559  0.01003  0.04612
# 1      0.00678  0.00407  ...  0.00136  0.01696  0.03596  0.01221  0.04545
# 2      0.01543  0.00782  ...  0.00596  0.01974  0.02489  0.03126  0.02036
# 3      0.00992  0.01567  ...  0.00366  0.01410  0.01671  0.03760  0.01932
# 4      0.03679  0.01380  ...  0.00604  0.01494  0.01734  0.04148  0.02483
# ...        ...      ...  ...      ...      ...      ...      ...      ...
# 13023  0.01367  0.01276  ...  0.00820  0.01367  0.01094  0.01367  0.02279
# 13024  0.00629  0.01451  ...  0.00145  0.00000  0.00048  0.00194  0.01306
# 13025  0.00356  0.01127  ...  0.00000  0.00000  0.00000  0.00178  0.01661
# 13026  0.01293  0.01319  ...  0.01142  0.01217  0.01196  0.02178  0.02510
# 13027  0.00600  0.01689  ...  0.00083  0.00041  0.00041  0.00451  0.01402
#
#            GAA      GAG      UAA      UAG      UGA
# 0      0.01203  0.04361  0.00251  0.00050  0.00000
# 1      0.01560  0.04410  0.00271  0.00068  0.00000
# 2      0.02242  0.02468  0.00391  0.00000  0.00144
# 3      0.03029  0.03446  0.00261  0.00157  0.00000
# 4      0.03359  0.03679  0.00000  0.00044  0.00131
# ...        ...      ...      ...      ...      ...
# 13023  0.02005  0.04102  0.00091  0.00091  0.00638
# 13024  0.01838  0.00677  0.00242  0.00097  0.01887
# 13025  0.02788  0.00297  0.00356  0.00119  0.02017
# 13026  0.02896  0.03959  0.00099  0.00079  0.00156
# 13027  0.01651  0.00783  0.00156  0.00114  0.02161
#
# [13028 rows x 69 columns]

# %% [markdown]
# ### **Preprocessing**

# %%
df.dtypes
# Out:
# Kingdom         object
# DNAtype          int64
# SpeciesID        int64
# Ncodons          int64
# SpeciesName     object
#                 ...
# GAA            float64
# GAG            float64
# UAA            float64
# UAG            float64
# UGA            float64
# Length: 69, dtype: object

# %%
encoder = preprocessing.LabelEncoder()
df["Kingdom"] = encoder.fit_transform(df["Kingdom"])

# %%
df.dtypes
# Out:
# Kingdom          int64
# DNAtype          int64
# SpeciesID        int64
# Ncodons          int64
# SpeciesName     object
#                 ...
# GAA            float64
# GAG            float64
# UAA            float64
# UAG            float64
# UGA            float64
# Length: 69, dtype: object

# %%
plot_hist(df, option=1)

# %%
df.drop(columns=["SpeciesID", "SpeciesName"], inplace=True) # "Ncodons"

# %%
df.shape
# Out:
# (13028, 67)

# %%
df["Kingdom"].value_counts(ascending=True, dropna=False)
# Out:
# 5       18
# 0      126
# 7      180
# 8      215
# 4      220
# 3      572
# 2     1345
# 10    2077
# 6     2523
# 9     2832
# 1     2920
# Name: Kingdom, dtype: int64

# %%
index = df["Kingdom"].value_counts(ascending=True, dropna=False).loc[lambda x : x < 1345].index
# print(index.to_list())

""" for k in index.to_list():
  df.drop(df[df["Kingdom"] == k].index, inplace=True) """
# Or
df = df[df.Kingdom.isin(index) == False]

# %%
df["Kingdom"].value_counts(ascending=True, dropna=False)
# Out:
# 2     1345
# 10    2077
# 6     2523
# 9     2832
# 1     2920
# Name: Kingdom, dtype: int64

# %%
df["DNAtype"].value_counts(ascending=True, dropna=False)
# Out:
# 6        1
# 7        1
# 3        2
# 9        2
# 5        2
# 11       2
# 12       5
# 4       31
# 2      816
# 1     2176
# 0     8659
# Name: DNAtype, dtype: int64

# %%
index = df["DNAtype"].value_counts(ascending=True, dropna=False).loc[lambda x : x < 816].index
# print(index.to_list())

""" for k in index.to_list():
  df.drop(df[df["DNAtype"] == k].index, inplace=True) """
# Or
df = df[df.DNAtype.isin(index) == False]

# %%
df["DNAtype"].value_counts(ascending=True, dropna=False)
# Out:
# 2     816
# 1    2176
# 0    8659
# Name: DNAtype, dtype: int64

# %%
df.dtypes
# Out:
# Kingdom      int64
# DNAtype      int64
# Ncodons      int64
# UUU         object
# UUC         object
#             ...
# GAA        float64
# GAG        float64
# UAA        float64
# UAG        float64
# UGA        float64
# Length: 67, dtype: object

# %%
# df["UUU"] = df["UUU"].astype("float") # ValueError: could not convert string to float
df["UUU"] = pd.to_numeric(df["UUU"], errors="coerce")
df["UUC"] = pd.to_numeric(df["UUC"], errors="coerce")

# %%
df.dtypes
# Out:
# Kingdom      int64
# DNAtype      int64
# Ncodons      int64
# UUU        float64
# UUC        float64
#             ...
# GAA        float64
# GAG        float64
# UAA        float64
# UAG        float64
# UGA        float64
# Length: 67, dtype: object

# %%
df.isnull().sum()
# Out:
# Kingdom    0
# DNAtype    0
# Ncodons    0
# UUU        2
# UUC        1
#           ..
# GAA        0
# GAG        0
# UAA        0
# UAG        0
# UGA        0
# Length: 67, dtype: int64

# %%
print(df.shape)
preview_dataset(df)
# Out:
# (11651, 67)
# Column name: Kingdom
# NANs: 0
# Negatives: 0
# Zeros: 0
# Positives: 11651
#
# 1     2918
# 9     2832
# 6     2490
# 10    2077
# 2     1334
# Name: Kingdom, dtype: int64
# Column name: DNAtype
# NANs: 0
# Negatives: 0
# Zeros: 8659
# Positives: 2992
#
# 0    8659
# 1    2176
# 2     816
# Name: DNAtype, dtype: int64
# Column name: Ncodons
# NANs: 0
# Negatives: 0
# Zeros: 0
# Positives: 11651
#
# 1784      58
# 1054      43
# 1014      38
# 1256      38
# 1047      35
#           ..
# 581662     1
# 45460      1
# 23493      1
# 22683      1
# 4304       1
# Name: Ncodons, Length: 6634, dtype: int64
# Column name: UUU
# NANs: 2
# Negatives: 0
# Zeros: 81
# Positives: 11568
#
# 0.00000    81
# 0.04536    34
# 0.04618    28
# 0.01423    16
# 0.01761    16
#            ..
# 0.04282     1
# 0.03981     1
# 0.03644     1
# 0.00486     1
# 0.02881     1
# Name: UUU, Length: 4676, dtype: int64
# Column name: UUC
# NANs: 1
# Negatives: 0
# Zeros: 16
# Positives: 11634
#
# 0.01911    43
# 0.02564    42
# 0.01433    19
# 0.01190    18
# 0.01146    18
#            ..
# 0.03579     1
# 0.03454     1
# 0.04299     1
# 0.03918     1
# 0.04089     1
# Name: UUC, Length: 3850, dtype: int64
# Column name: UUA
# NANs: 0
# Negatives: 0
# Zeros: 442
# Positives: 11209
#
# 0.00000    442
# 0.01513     40
# 0.03748     32
# 0.00093     17
# 0.00015     14
#           ...
# 0.01055      1
# 0.01279      1
# 0.03853      1
# 0.03987      1
# 0.03843      1
# Name: UUA, Length: 4555, dtype: int64
# Column name: UUG
# NANs: 0
# Negatives: 0
# Zeros: 313
# Positives: 11338
#
# 0.00000    313
# 0.01035     42
# 0.03156     34
# 0.01774     22
# 0.00352     17
#           ...
# 0.00250      1
# 0.03155      1
# 0.03052      1
# 0.03108      1
# 0.00112      1
# Name: UUG, Length: 3223, dtype: int64
# Column name: CUU
# NANs: 0
# Negatives: 0
# Zeros: 34
# Positives: 11617
#
# 0.02564    43
# 0.02627    35
# 0.00000    34
# 0.01312    20
# 0.00945    18
#            ..
# 0.03097     1
# 0.02452     1
# 0.00511     1
# 0.03335     1
# 0.00209     1
# Name: CUU, Length: 3560, dtype: int64
# Column name: CUC
# NANs: 0
# Negatives: 0
# Zeros: 234
# Positives: 11417
#
# 0.00000    234
# 0.00789     39
# 0.01513     37
# 0.00794     20
# 0.00587     20
#           ...
# 0.03216      1
# 0.04473      1
# 0.01963      1
# 0.01863      1
# 0.02408      1
# Name: CUC, Length: 4159, dtype: int64
# Column name: CUA
# NANs: 0
# Negatives: 0
# Zeros: 268
# Positives: 11383
#
# 0.00000    268
# 0.00796     38
# 0.01775     30
# 0.01389     24
# 0.00907     22
#           ...
# 0.06141      1
# 0.06157      1
# 0.02929      1
# 0.10531      1
# 0.05855      1
# Name: CUA, Length: 3540, dtype: int64
# Column name: CUG
# NANs: 0
# Negatives: 0
# Zeros: 187
# Positives: 11464
#
# 0.00000    187
# 0.00789     42
# 0.00318     41
# 0.00975     25
# 0.00595     22
#           ...
# 0.06991      1
# 0.05289      1
# 0.03710      1
# 0.03200      1
# 0.05573      1
# Name: CUG, Length: 4375, dtype: int64
# Column name: AUU
# NANs: 0
# Negatives: 0
# Zeros: 50
# Positives: 11601
#
# 0.00000    50
# 0.04734    38
# 0.04220    28
# 0.02170    14
# 0.02092    13
#            ..
# 0.03294     1
# 0.04628     1
# 0.03199     1
# 0.02572     1
# 0.03938     1
# Name: AUU, Length: 4930, dtype: int64
# Column name: AUC
# NANs: 0
# Negatives: 0
# Zeros: 13
# Positives: 11638
#
# 0.00986    47
# 0.00796    29
# 0.01124    17
# 0.00992    17
# 0.01701    16
#            ..
# 0.00624     1
# 0.03512     1
# 0.04854     1
# 0.03601     1
# 0.04224     1
# Name: AUC, Length: 4278, dtype: int64
# Column name: AUA
# NANs: 0
# Negatives: 0
# Zeros: 284
# Positives: 11367
#
# 0.00000    284
# 0.01775     40
# 0.01115     39
# 0.02579     28
# 0.01235     18
#           ...
# 0.03194      1
# 0.00668      1
# 0.07920      1
# 0.06503      1
# 0.00510      1
# Name: AUA, Length: 4040, dtype: int64
# Column name: AUG
# NANs: 0
# Negatives: 0
# Zeros: 13
# Positives: 11638
#
# 0.01775    37
# 0.01592    35
# 0.02092    19
# 0.02423    18
# 0.02448    18
#            ..
# 0.05315     1
# 0.09735     1
# 0.02979     1
# 0.00912     1
# 0.00394     1
# Name: AUG, Length: 3080, dtype: int64
# Column name: GUU
# NANs: 0
# Negatives: 0
# Zeros: 100
# Positives: 11551
#
# 0.00000    100
# 0.01183     42
# 0.03901     26
# 0.00860     25
# 0.00288     23
#           ...
# 0.02480      1
# 0.03015      1
# 0.00508      1
# 0.00175      1
# 0.00100      1
# Name: GUU, Length: 3556, dtype: int64
# Column name: GUC
# NANs: 0
# Negatives: 0
# Zeros: 89
# Positives: 11562
#
# 0.00000    89
# 0.00592    49
# 0.01513    46
# 0.00391    22
# 0.00287    22
#            ..
# 0.04112     1
# 0.04139     1
# 0.04472     1
# 0.03525     1
# 0.03385     1
# Name: GUC, Length: 3541, dtype: int64
# Column name: GUA
# NANs: 0
# Negatives: 0
# Zeros: 109
# Positives: 11542
#
# 0.00000    109
# 0.01775     44
# 0.00955     40
# 0.00287     26
# 0.00573     22
#           ...
# 0.03579      1
# 0.03414      1
# 0.03187      1
# 0.05341      1
# 0.01679      1
# Name: GUA, Length: 3012, dtype: int64
# Column name: GUG
# NANs: 0
# Negatives: 0
# Zeros: 298
# Positives: 11353
#
# 0.00000    298
# 0.00592     45
# 0.01035     36
# 0.00587     18
# 0.00288     18
#           ...
# 0.01909      1
# 0.01964      1
# 0.02466      1
# 0.03001      1
# 0.03697      1
# Name: GUG, Length: 3880, dtype: int64
# Column name: GCU
# NANs: 0
# Negatives: 0
# Zeros: 20
# Positives: 11631
#
# 0.01972    36
# 0.03742    27
# 0.00000    20
# 0.00992    18
# 0.01957    17
#            ..
# 0.04859     1
# 0.07489     1
# 0.06039     1
# 0.00255     1
# 0.01743     1
# Name: GCU, Length: 3629, dtype: int64
# Column name: GCC
# NANs: 0
# Negatives: 0
# Zeros: 85
# Positives: 11566
#
# 0.00000    85
# 0.00789    43
# 0.00955    37
# 0.00978    21
# 0.00198    19
#            ..
# 0.04713     1
# 0.05580     1
# 0.05905     1
# 0.04440     1
# 0.03470     1
# Name: GCC, Length: 4879, dtype: int64
# Column name: GCA
# NANs: 0
# Negatives: 0
# Zeros: 25
# Positives: 11626
#
# 0.00789    41
# 0.01354    32
# 0.00000    25
# 0.02292    19
# 0.00591    16
#            ..
# 0.00650     1
# 0.00332     1
# 0.03417     1
# 0.00312     1
# 0.02543     1
# Name: GCA, Length: 3356, dtype: int64
# Column name: GCG
# NANs: 0
# Negatives: 0
# Zeros: 583
# Positives: 11068
#
# 0.00000    583
# 0.00197     70
# 0.00398     45
# 0.00196     41
# 0.00198     36
#           ...
# 0.05514      1
# 0.02036      1
# 0.04456      1
# 0.04860      1
# 0.02149      1
# Name: GCG, Length: 3484, dtype: int64
# Column name: CCU
# NANs: 0
# Negatives: 0
# Zeros: 51
# Positives: 11600
#
# 0.00000    51
# 0.01183    33
# 0.02707    29
# 0.00986    24
# 0.01190    24
#            ..
# 0.00157     1
# 0.06183     1
# 0.00138     1
# 0.03782     1
# 0.03249     1
# Name: CCU, Length: 2731, dtype: int64
# Column name: CCC
# NANs: 0
# Negatives: 0
# Zeros: 197
# Positives: 11454
#
# 0.00000    197
# 0.00239     43
# 0.00787     23
# 0.00403     21
# 0.00587     21
#           ...
# 0.02707      1
# 0.03046      1
# 0.04692      1
# 0.02947      1
# 0.04734      1
# Name: CCC, Length: 3147, dtype: int64
# Column name: CCA
# NANs: 0
# Negatives: 0
# Zeros: 66
# Positives: 11585
#
# 0.00000    66
# 0.01381    47
# 0.01513    43
# 0.00860    35
# 0.01389    22
#            ..
# 0.03110     1
# 0.02906     1
# 0.04523     1
# 0.04310     1
# 0.07844     1
# Name: CCA, Length: 3312, dtype: int64
# Column name: CCG
# NANs: 0
# Negatives: 0
# Zeros: 561
# Positives: 11090
#
# 0.00000    561
# 0.00159     51
# 0.00394     36
# 0.00196     32
# 0.00198     29
#           ...
# 0.00001      1
# 0.02796      1
# 0.01741      1
# 0.02770      1
# 0.01181      1
# Name: CCG, Length: 2832, dtype: int64
# Column name: UGG
# NANs: 0
# Negatives: 0
# Zeros: 252
# Positives: 11399
#
# 0.00000    252
# 0.01578     45
# 0.00876     44
# 0.01389     27
# 0.01566     26
#           ...
# 0.02565      1
# 0.02788      1
# 0.02850      1
# 0.02727      1
# 0.00717      1
# Name: UGG, Length: 2552, dtype: int64
# Column name: GGU
# NANs: 0
# Negatives: 0
# Zeros: 117
# Positives: 11534
#
# 0.00000    117
# 0.00789     51
# 0.02468     34
# 0.00787     22
# 0.00794     19
#           ...
# 0.02693      1
# 0.03856      1
# 0.02972      1
# 0.02368      1
# 0.00070      1
# Name: GGU, Length: 3531, dtype: int64
# Column name: GGC
# NANs: 0
# Negatives: 0
# Zeros: 174
# Positives: 11477
#
# 0.00000    174
# 0.00592     37
# 0.00197     36
# 0.00198     29
# 0.01911     28
#           ...
# 0.02916      1
# 0.03856      1
# 0.02963      1
# 0.02600      1
# 0.00162      1
# Name: GGC, Length: 4283, dtype: int64
# Column name: GGA
# NANs: 0
# Negatives: 0
# Zeros: 33
# Positives: 11618
#
# 0.01592    48
# 0.01183    42
# 0.00000    33
# 0.01992    20
# 0.02092    19
#            ..
# 0.05314     1
# 0.00448     1
# 0.01093     1
# 0.00545     1
# 0.00511     1
# Name: GGA, Length: 3380, dtype: int64
# Column name: GGG
# NANs: 0
# Negatives: 0
# Zeros: 173
# Positives: 11478
#
# 0.00000    173
# 0.01183     42
# 0.00318     39
# 0.00287     29
# 0.00794     25
#           ...
# 0.01840      1
# 0.00232      1
# 0.02595      1
# 0.03134      1
# 0.00336      1
# Name: GGG, Length: 2573, dtype: int64
# Column name: UCU
# NANs: 0
# Negatives: 0
# Zeros: 115
# Positives: 11536
#
# 0.00000    115
# 0.00573     24
# 0.00860     24
# 0.04734     23
# 0.03424     19
#           ...
# 0.03280      1
# 0.03033      1
# 0.02789      1
# 0.02886      1
# 0.00832      1
# Name: UCU, Length: 3201, dtype: int64
# Column name: UCC
# NANs: 0
# Negatives: 0
# Zeros: 98
# Positives: 11553
#
# 0.00000    98
# 0.01972    36
# 0.00478    33
# 0.01575    19
# 0.00780    18
#            ..
# 0.03056     1
# 0.02310     1
# 0.03509     1
# 0.03182     1
# 0.03176     1
# Name: UCC, Length: 2932, dtype: int64
# Column name: UCA
# NANs: 0
# Negatives: 0
# Zeros: 101
# Positives: 11550
#
# 0.00000    101
# 0.02761     39
# 0.02309     28
# 0.01587     20
# 0.02579     18
#           ...
# 0.02551      1
# 0.02556      1
# 0.02413      1
# 0.03383      1
# 0.02243      1
# Name: UCA, Length: 3200, dtype: int64
# Column name: UCG
# NANs: 0
# Negatives: 0
# Zeros: 551
# Positives: 11100
#
# 0.00000    551
# 0.00287     41
# 0.00239     38
# 0.01183     36
# 0.00262     26
#           ...
# 0.02506      1
# 0.02419      1
# 0.02396      1
# 0.02320      1
# 0.01841      1
# Name: UCG, Length: 2286, dtype: int64
# Column name: AGU
# NANs: 0
# Negatives: 0
# Zeros: 443
# Positives: 11208
#
# 0.00000    443
# 0.01381     43
# 0.00955     31
# 0.00288     29
# 0.00336     29
#           ...
# 0.02171      1
# 0.00017      1
# 0.02307      1
# 0.02856      1
# 0.00053      1
# Name: AGU, Length: 2418, dtype: int64
# Column name: AGC
# NANs: 0
# Negatives: 0
# Zeros: 167
# Positives: 11484
#
# 0.00000    167
# 0.00394     50
# 0.00262     42
# 0.00478     42
# 0.00860     30
#           ...
# 0.01765      1
# 0.02438      1
# 0.02166      1
# 0.03094      1
# 0.02553      1
# Name: AGC, Length: 2503, dtype: int64
# Column name: ACU
# NANs: 0
# Negatives: 0
# Zeros: 64
# Positives: 11587
#
# 0.00000    64
# 0.01183    42
# 0.03662    29
# 0.01587    22
# 0.01761    20
#            ..
# 0.04104     1
# 0.00222     1
# 0.00583     1
# 0.00441     1
# 0.03050     1
# Name: ACU, Length: 3200, dtype: int64
# Column name: ACC
# NANs: 0
# Negatives: 0
# Zeros: 70
# Positives: 11581
#
# 0.00000    70
# 0.00197    47
# 0.00955    38
# 0.00196    30
# 0.01081    16
#            ..
# 0.03070     1
# 0.00237     1
# 0.04129     1
# 0.02023     1
# 0.02451     1
# Name: ACC, Length: 4102, dtype: int64
# Column name: ACA
# NANs: 0
# Negatives: 0
# Zeros: 99
# Positives: 11552
#
# 0.00000    99
# 0.00197    43
# 0.02866    25
# 0.00196    22
# 0.01481    17
#            ..
# 0.04727     1
# 0.00803     1
# 0.00854     1
# 0.01003     1
# 0.03551     1
# Name: ACA, Length: 3910, dtype: int64
# Column name: ACG
# NANs: 0
# Negatives: 0
# Zeros: 454
# Positives: 11197
#
# 0.00000    454
# 0.00394     54
# 0.00318     43
# 0.00198     35
# 0.00287     32
#           ...
# 0.02104      1
# 0.02340      1
# 0.01804      1
# 0.02223      1
# 0.00928      1
# Name: ACG, Length: 2458, dtype: int64
# Column name: UAU
# NANs: 0
# Negatives: 0
# Zeros: 121
# Positives: 11530
#
# 0.00000    121
# 0.04536     31
# 0.00573     26
# 0.02787     25
# 0.00576     23
#           ...
# 0.02017      1
# 0.05877      1
# 0.05690      1
# 0.02452      1
# 0.00023      1
# Name: UAU, Length: 3886, dtype: int64
# Column name: UAC
# NANs: 0
# Negatives: 0
# Zeros: 36
# Positives: 11615
#
# 0.01433    53
# 0.00986    41
# 0.00000    36
# 0.01441    25
# 0.01719    24
#            ..
# 0.03845     1
# 0.02510     1
# 0.04215     1
# 0.03086     1
# 0.03237     1
# Name: UAC, Length: 2922, dtype: int64
# Column name: CAA
# NANs: 0
# Negatives: 0
# Zeros: 49
# Positives: 11602
#
# 0.00000    49
# 0.02367    46
# 0.03503    36
# 0.02579    20
# 0.01837    18
#            ..
# 0.04267     1
# 0.03290     1
# 0.04100     1
# 0.01207     1
# 0.01345     1
# Name: CAA, Length: 3623, dtype: int64
# Column name: CAG
# NANs: 0
# Negatives: 0
# Zeros: 264
# Positives: 11387
#
# 0.00000    264
# 0.00789     44
# 0.00262     30
# 0.00392     24
# 0.00287     23
#           ...
# 0.03537      1
# 0.03450      1
# 0.02612      1
# 0.04677      1
# 0.00839      1
# Name: CAG, Length: 3581, dtype: int64
# Column name: AAU
# NANs: 0
# Negatives: 0
# Zeros: 59
# Positives: 11592
#
# 0.00000    59
# 0.04536    38
# 0.04140    20
# 0.00860    20
# 0.00288    15
#            ..
# 0.00018     1
# 0.00326     1
# 0.00874     1
# 0.05235     1
# 0.01637     1
# Name: AAU, Length: 4578, dtype: int64
# Column name: AAC
# NANs: 0
# Negatives: 0
# Zeros: 22
# Positives: 11629
#
# 0.00986    40
# 0.02229    33
# 0.00000    22
# 0.01433    20
# 0.02006    20
#            ..
# 0.00732     1
# 0.00695     1
# 0.00714     1
# 0.04175     1
# 0.05755     1
# Name: AAC, Length: 3598, dtype: int64
# Column name: UGU
# NANs: 0
# Negatives: 0
# Zeros: 714
# Positives: 10937
#
# 0.00000    714
# 0.00986     52
# 0.01592     30
# 0.00168     28
# 0.00224     27
#           ...
# 0.03007      1
# 0.02655      1
# 0.01586      1
# 0.03609      1
# 0.02927      1
# Name: UGU, Length: 2194, dtype: int64
# Column name: UGC
# NANs: 0
# Negatives: 0
# Zeros: 496
# Positives: 11155
#
# 0.00000    496
# 0.00287     57
# 0.00196     37
# 0.00197     31
# 0.00288     31
#           ...
# 0.02470      1
# 0.02219      1
# 0.01959      1
# 0.01782      1
# 0.02716      1
# Name: UGC, Length: 2136, dtype: int64
# Column name: CAU
# NANs: 0
# Negatives: 0
# Zeros: 138
# Positives: 11513
#
# 0.00000    138
# 0.01035     43
# 0.00860     38
# 0.03353     28
# 0.00573     25
#           ...
# 0.00245      1
# 0.02451      1
# 0.03138      1
# 0.02753      1
# 0.00025      1
# Name: CAU, Length: 2591, dtype: int64
# Column name: CAC
# NANs: 0
# Negatives: 0
# Zeros: 84
# Positives: 11567
#
# 0.00000    84
# 0.00789    47
# 0.00159    37
# 0.01433    22
# 0.00783    20
#            ..
# 0.02072     1
# 0.00017     1
# 0.00169     1
# 0.02225     1
# 0.02753     1
# Name: CAC, Length: 2588, dtype: int64
# Column name: AAA
# NANs: 0
# Negatives: 0
# Zeros: 55
# Positives: 11596
#
# 0.00000    55
# 0.04339    35
# 0.02548    27
# 0.02362    26
# 0.02579    21
#            ..
# 0.00817     1
# 0.09140     1
# 0.05575     1
# 0.04083     1
# 0.01797     1
# Name: AAA, Length: 5142, dtype: int64
# Column name: AAG
# NANs: 0
# Negatives: 0
# Zeros: 272
# Positives: 11379
#
# 0.00000    272
# 0.01972     36
# 0.02070     32
# 0.00262     26
# 0.00168     20
#           ...
# 0.04540      1
# 0.01075      1
# 0.00959      1
# 0.05341      1
# 0.00116      1
# Name: AAG, Length: 4405, dtype: int64
# Column name: CGU
# NANs: 0
# Negatives: 0
# Zeros: 419
# Positives: 11232
#
# 0.00000    419
# 0.00287     67
# 0.00557     42
# 0.00319     33
# 0.00168     32
#           ...
# 0.02203      1
# 0.02001      1
# 0.01663      1
# 0.01934      1
# 0.00023      1
# Name: CGU, Length: 2214, dtype: int64
# Column name: CGC
# NANs: 0
# Negatives: 0
# Zeros: 450
# Positives: 11201
#
# 0.00000    450
# 0.00592     49
# 0.00288     48
# 0.00239     45
# 0.00196     42
#           ...
# 0.03879      1
# 0.02663      1
# 0.02595      1
# 0.03822      1
# 0.01512      1
# Name: CGC, Length: 3103, dtype: int64
# Column name: CGA
# NANs: 0
# Negatives: 0
# Zeros: 325
# Positives: 11326
#
# 0.00000    325
# 0.00318     43
# 0.00319     38
# 0.00576     37
# 0.01578     24
#           ...
# 0.01310      1
# 0.02389      1
# 0.00028      1
# 0.01764      1
# 0.01208      1
# Name: CGA, Length: 1809, dtype: int64
# Column name: CGG
# NANs: 0
# Negatives: 0
# Zeros: 1046
# Positives: 10605
#
# 0.00000    1046
# 0.00394      56
# 0.00159      42
# 0.00057      34
# 0.00280      34
#            ...
# 0.04070       1
# 0.03282       1
# 0.03625       1
# 0.02526       1
# 0.00925       1
# Name: CGG, Length: 2080, dtype: int64
# Column name: AGA
# NANs: 0
# Negatives: 0
# Zeros: 1588
# Positives: 10063
#
# 0.00000    1588
# 0.02170      37
# 0.01587      24
# 0.00032      23
# 0.01115      22
#            ...
# 0.02332       1
# 0.02514       1
# 0.00483       1
# 0.02059       1
# 0.00962       1
# Name: AGA, Length: 2799, dtype: int64
# Column name: AGG
# NANs: 0
# Negatives: 0
# Zeros: 1595
# Positives: 10056
#
# 0.00000    1595
# 0.00986      43
# 0.00391      37
# 0.00056      36
# 0.01035      33
#            ...
# 0.02708       1
# 0.02563       1
# 0.01742       1
# 0.02333       1
# 0.02368       1
# Name: AGG, Length: 2166, dtype: int64
# Column name: GAU
# NANs: 0
# Negatives: 0
# Zeros: 246
# Positives: 11405
#
# 0.00000    246
# 0.02367     41
# 0.03901     31
# 0.00287     25
# 0.00262     19
#           ...
# 0.03554      1
# 0.00280      1
# 0.05027      1
# 0.02848      1
# 0.00046      1
# Name: GAU, Length: 4409, dtype: int64
# Column name: GAC
# NANs: 0
# Negatives: 0
# Zeros: 110
# Positives: 11541
#
# 0.00000    110
# 0.00789     44
# 0.00287     37
# 0.01911     28
# 0.00992     26
#           ...
# 0.06474      1
# 0.05846      1
# 0.05541      1
# 0.01605      1
# 0.03452      1
# Name: GAC, Length: 4335, dtype: int64
# Column name: GAA
# NANs: 0
# Negatives: 0
# Zeros: 14
# Positives: 11637
#
# 0.01433    41
# 0.03353    35
# 0.01837    27
# 0.01831    26
# 0.01153    24
#            ..
# 0.03865     1
# 0.03324     1
# 0.04104     1
# 0.03440     1
# 0.01608     1
# Name: GAA, Length: 4689, dtype: int64
# Column name: GAG
# NANs: 0
# Negatives: 0
# Zeros: 298
# Positives: 11353
#
# 0.00000    298
# 0.01381     36
# 0.01672     32
# 0.00978     19
# 0.00287     18
#           ...
# 0.04888      1
# 0.04640      1
# 0.04211      1
# 0.03155      1
# 0.00188      1
# Name: GAG, Length: 4526, dtype: int64
# Column name: UAA
# NANs: 0
# Negatives: 0
# Zeros: 1482
# Positives: 10169
#
# 0.00000    1482
# 0.00046     117
# 0.00287      96
# 0.00080      82
# 0.00073      72
#            ...
# 0.00751       1
# 0.00866       1
# 0.00611       1
# 0.00401       1
# 0.01532       1
# Name: UAA, Length: 677, dtype: int64
# Column name: UAG
# NANs: 0
# Negatives: 0
# Zeros: 3716
# Positives: 7935
#
# 0.00000    3716
# 0.00056     111
# 0.00090     107
# 0.00044     102
# 0.00047      97
#            ...
# 0.01250       1
# 0.00410       1
# 0.01142       1
# 0.00696       1
# 0.00630       1
# Name: UAG, Length: 419, dtype: int64
# Column name: UGA
# NANs: 0
# Negatives: 0
# Zeros: 2088
# Positives: 9563
#
# 0.00000    2088
# 0.00197      98
# 0.00090      78
# 0.00196      69
# 0.00040      68
#            ...
# 0.02008       1
# 0.01893       1
# 0.00790       1
# 0.02183       1
# 0.02556       1
# Name: UGA, Length: 1604, dtype: int64

# %%
df.dropna(inplace=True)

# %%
print(df.shape)
preview_dataset(df)
# Out:
# (11649, 67)
# Column name: Kingdom
# NANs: 0
# Negatives: 0
# Zeros: 0
# Positives: 11649
#
# 1     2917
# 9     2831
# 6     2490
# 10    2077
# 2     1334
# Name: Kingdom, dtype: int64
# Column name: DNAtype
# NANs: 0
# Negatives: 0
# Zeros: 8657
# Positives: 2992
#
# 0    8657
# 1    2176
# 2     816
# Name: DNAtype, dtype: int64
# Column name: Ncodons
# NANs: 0
# Negatives: 0
# Zeros: 0
# Positives: 11649
#
# 1784      58
# 1054      43
# 1256      38
# 1014      38
# 1047      35
#           ..
# 581662     1
# 45460      1
# 23493      1
# 22683      1
# 4304       1
# Name: Ncodons, Length: 6634, dtype: int64
# Column name: UUU
# NANs: 0
# Negatives: 0
# Zeros: 81
# Positives: 11568
#
# 0.00000    81
# 0.04536    34
# 0.04618    28
# 0.01423    16
# 0.01761    16
#            ..
# 0.04282     1
# 0.03981     1
# 0.03644     1
# 0.00486     1
# 0.02881     1
# Name: UUU, Length: 4675, dtype: int64
# Column name: UUC
# NANs: 0
# Negatives: 0
# Zeros: 16
# Positives: 11633
#
# 0.01911    43
# 0.02564    42
# 0.01433    19
# 0.01190    18
# 0.01134    18
#            ..
# 0.03579     1
# 0.03454     1
# 0.04299     1
# 0.03918     1
# 0.04089     1
# Name: UUC, Length: 3848, dtype: int64
# Column name: UUA
# NANs: 0
# Negatives: 0
# Zeros: 442
# Positives: 11207
#
# 0.00000    442
# 0.01513     40
# 0.03748     32
# 0.00093     17
# 0.00012     14
#           ...
# 0.02384      1
# 0.06885      1
# 0.03878      1
# 0.05330      1
# 0.03843      1
# Name: UUA, Length: 4555, dtype: int64
# Column name: UUG
# NANs: 0
# Negatives: 0
# Zeros: 313
# Positives: 11336
#
# 0.00000    313
# 0.01035     42
# 0.03156     34
# 0.01774     22
# 0.00352     17
#           ...
# 0.02744      1
# 0.01672      1
# 0.00250      1
# 0.03155      1
# 0.00112      1
# Name: UUG, Length: 3223, dtype: int64
# Column name: CUU
# NANs: 0
# Negatives: 0
# Zeros: 34
# Positives: 11615
#
# 0.02564    43
# 0.02627    35
# 0.00000    34
# 0.01312    20
# 0.00945    18
#            ..
# 0.03097     1
# 0.02452     1
# 0.00511     1
# 0.03335     1
# 0.00209     1
# Name: CUU, Length: 3560, dtype: int64
# Column name: CUC
# NANs: 0
# Negatives: 0
# Zeros: 234
# Positives: 11415
#
# 0.00000    234
# 0.00789     39
# 0.01513     37
# 0.00794     20
# 0.00587     20
#           ...
# 0.03216      1
# 0.04473      1
# 0.01963      1
# 0.01863      1
# 0.02408      1
# Name: CUC, Length: 4158, dtype: int64
# Column name: CUA
# NANs: 0
# Negatives: 0
# Zeros: 268
# Positives: 11381
#
# 0.00000    268
# 0.00796     38
# 0.01775     30
# 0.01389     24
# 0.00907     22
#           ...
# 0.06141      1
# 0.06157      1
# 0.02929      1
# 0.10531      1
# 0.05855      1
# Name: CUA, Length: 3540, dtype: int64
# Column name: CUG
# NANs: 0
# Negatives: 0
# Zeros: 187
# Positives: 11462
#
# 0.00000    187
# 0.00789     42
# 0.00318     41
# 0.00975     25
# 0.00595     22
#           ...
# 0.06804      1
# 0.06991      1
# 0.05289      1
# 0.03710      1
# 0.05573      1
# Name: CUG, Length: 4375, dtype: int64
# Column name: AUU
# NANs: 0
# Negatives: 0
# Zeros: 50
# Positives: 11599
#
# 0.00000    50
# 0.04734    38
# 0.04220    28
# 0.02170    14
# 0.02092    13
#            ..
# 0.04628     1
# 0.03199     1
# 0.02572     1
# 0.00594     1
# 0.03938     1
# Name: AUU, Length: 4930, dtype: int64
# Column name: AUC
# NANs: 0
# Negatives: 0
# Zeros: 13
# Positives: 11636
#
# 0.00986    47
# 0.00796    29
# 0.01124    17
# 0.00992    17
# 0.01701    16
#            ..
# 0.00624     1
# 0.03512     1
# 0.04854     1
# 0.03601     1
# 0.04224     1
# Name: AUC, Length: 4277, dtype: int64
# Column name: AUA
# NANs: 0
# Negatives: 0
# Zeros: 284
# Positives: 11365
#
# 0.00000    284
# 0.01775     40
# 0.01115     39
# 0.02579     28
# 0.02362     18
#           ...
# 0.03194      1
# 0.00668      1
# 0.07920      1
# 0.06503      1
# 0.00510      1
# Name: AUA, Length: 4040, dtype: int64
# Column name: AUG
# NANs: 0
# Negatives: 0
# Zeros: 13
# Positives: 11636
#
# 0.01775    37
# 0.01592    35
# 0.02092    19
# 0.02423    18
# 0.00287    18
#            ..
# 0.03634     1
# 0.03556     1
# 0.03377     1
# 0.00733     1
# 0.00394     1
# Name: AUG, Length: 3079, dtype: int64
# Column name: GUU
# NANs: 0
# Negatives: 0
# Zeros: 100
# Positives: 11549
#
# 0.00000    100
# 0.01183     42
# 0.03901     26
# 0.00860     25
# 0.00288     23
#           ...
# 0.02837      1
# 0.02480      1
# 0.03015      1
# 0.00508      1
# 0.00100      1
# Name: GUU, Length: 3556, dtype: int64
# Column name: GUC
# NANs: 0
# Negatives: 0
# Zeros: 89
# Positives: 11560
#
# 0.00000    89
# 0.00592    49
# 0.01513    46
# 0.00287    22
# 0.00391    22
#            ..
# 0.03470     1
# 0.04472     1
# 0.04139     1
# 0.03525     1
# 0.03385     1
# Name: GUC, Length: 3541, dtype: int64
# Column name: GUA
# NANs: 0
# Negatives: 0
# Zeros: 109
# Positives: 11540
#
# 0.00000    109
# 0.01775     44
# 0.00955     40
# 0.00287     26
# 0.00573     22
#           ...
# 0.03579      1
# 0.03414      1
# 0.03187      1
# 0.05341      1
# 0.01679      1
# Name: GUA, Length: 3012, dtype: int64
# Column name: GUG
# NANs: 0
# Negatives: 0
# Zeros: 298
# Positives: 11351
#
# 0.00000    298
# 0.00592     45
# 0.01035     36
# 0.00288     18
# 0.00587     18
#           ...
# 0.02374      1
# 0.04280      1
# 0.04237      1
# 0.05261      1
# 0.03697      1
# Name: GUG, Length: 3880, dtype: int64
# Column name: GCU
# NANs: 0
# Negatives: 0
# Zeros: 20
# Positives: 11629
#
# 0.01972    36
# 0.03742    27
# 0.00000    20
# 0.00992    18
# 0.01957    17
#            ..
# 0.00604     1
# 0.00684     1
# 0.00304     1
# 0.00908     1
# 0.01743     1
# Name: GCU, Length: 3628, dtype: int64
# Column name: GCC
# NANs: 0
# Negatives: 0
# Zeros: 85
# Positives: 11564
#
# 0.00000    85
# 0.00789    43
# 0.00955    37
# 0.00978    21
# 0.00198    19
#            ..
# 0.06120     1
# 0.04713     1
# 0.05580     1
# 0.05905     1
# 0.03470     1
# Name: GCC, Length: 4878, dtype: int64
# Column name: GCA
# NANs: 0
# Negatives: 0
# Zeros: 25
# Positives: 11624
#
# 0.00789    41
# 0.01354    32
# 0.00000    25
# 0.02292    19
# 0.00591    16
#            ..
# 0.00650     1
# 0.00332     1
# 0.03417     1
# 0.00312     1
# 0.02543     1
# Name: GCA, Length: 3356, dtype: int64
# Column name: GCG
# NANs: 0
# Negatives: 0
# Zeros: 583
# Positives: 11066
#
# 0.00000    583
# 0.00197     70
# 0.00398     45
# 0.00196     41
# 0.00198     36
#           ...
# 0.04433      1
# 0.03223      1
# 0.01364      1
# 0.01594      1
# 0.02149      1
# Name: GCG, Length: 3483, dtype: int64
# Column name: CCU
# NANs: 0
# Negatives: 0
# Zeros: 51
# Positives: 11598
#
# 0.00000    51
# 0.01183    33
# 0.02707    29
# 0.00986    24
# 0.01190    24
#            ..
# 0.00157     1
# 0.06183     1
# 0.00138     1
# 0.03782     1
# 0.03249     1
# Name: CCU, Length: 2731, dtype: int64
# Column name: CCC
# NANs: 0
# Negatives: 0
# Zeros: 197
# Positives: 11452
#
# 0.00000    197
# 0.00239     43
# 0.00787     23
# 0.00403     21
# 0.00587     21
#           ...
# 0.03046      1
# 0.04692      1
# 0.02947      1
# 0.01343      1
# 0.04734      1
# Name: CCC, Length: 3147, dtype: int64
# Column name: CCA
# NANs: 0
# Negatives: 0
# Zeros: 66
# Positives: 11583
#
# 0.00000    66
# 0.01381    47
# 0.01513    43
# 0.00860    35
# 0.01389    22
#            ..
# 0.03110     1
# 0.02906     1
# 0.04523     1
# 0.04310     1
# 0.07844     1
# Name: CCA, Length: 3312, dtype: int64
# Column name: CCG
# NANs: 0
# Negatives: 0
# Zeros: 561
# Positives: 11088
#
# 0.00000    561
# 0.00159     51
# 0.00394     36
# 0.00196     32
# 0.00198     29
#           ...
# 0.02796      1
# 0.00001      1
# 0.02770      1
# 0.02258      1
# 0.01181      1
# Name: CCG, Length: 2832, dtype: int64
# Column name: UGG
# NANs: 0
# Negatives: 0
# Zeros: 252
# Positives: 11397
#
# 0.00000    252
# 0.01578     45
# 0.00876     44
# 0.01389     27
# 0.01566     26
#           ...
# 0.01913      1
# 0.04545      1
# 0.02257      1
# 0.02713      1
# 0.00717      1
# Name: UGG, Length: 2552, dtype: int64
# Column name: GGU
# NANs: 0
# Negatives: 0
# Zeros: 117
# Positives: 11532
#
# 0.00000    117
# 0.00789     51
# 0.02468     34
# 0.00787     22
# 0.00794     19
#           ...
# 0.03856      1
# 0.02972      1
# 0.02368      1
# 0.02992      1
# 0.00070      1
# Name: GGU, Length: 3531, dtype: int64
# Column name: GGC
# NANs: 0
# Negatives: 0
# Zeros: 174
# Positives: 11475
#
# 0.00000    174
# 0.00592     37
# 0.00197     36
# 0.00198     29
# 0.01911     28
#           ...
# 0.05067      1
# 0.02313      1
# 0.05898      1
# 0.04601      1
# 0.00162      1
# Name: GGC, Length: 4282, dtype: int64
# Column name: GGA
# NANs: 0
# Negatives: 0
# Zeros: 33
# Positives: 11616
#
# 0.01592    48
# 0.01183    42
# 0.00000    33
# 0.01992    20
# 0.02092    19
#            ..
# 0.05314     1
# 0.00448     1
# 0.01093     1
# 0.00545     1
# 0.00511     1
# Name: GGA, Length: 3380, dtype: int64
# Column name: GGG
# NANs: 0
# Negatives: 0
# Zeros: 173
# Positives: 11476
#
# 0.00000    173
# 0.01183     42
# 0.00318     39
# 0.00287     29
# 0.00794     25
#           ...
# 0.01840      1
# 0.00232      1
# 0.02595      1
# 0.03134      1
# 0.00336      1
# Name: GGG, Length: 2573, dtype: int64
# Column name: UCU
# NANs: 0
# Negatives: 0
# Zeros: 115
# Positives: 11534
#
# 0.00000    115
# 0.00573     24
# 0.00860     24
# 0.04734     23
# 0.03424     19
#           ...
# 0.04339      1
# 0.02991      1
# 0.04212      1
# 0.02687      1
# 0.00832      1
# Name: UCU, Length: 3201, dtype: int64
# Column name: UCC
# NANs: 0
# Negatives: 0
# Zeros: 98
# Positives: 11551
#
# 0.00000    98
# 0.01972    36
# 0.00478    33
# 0.01575    19
# 0.00780    18
#            ..
# 0.02310     1
# 0.03509     1
# 0.03182     1
# 0.00097     1
# 0.03176     1
# Name: UCC, Length: 2931, dtype: int64
# Column name: UCA
# NANs: 0
# Negatives: 0
# Zeros: 101
# Positives: 11548
#
# 0.00000    101
# 0.02761     39
# 0.02309     28
# 0.01587     20
# 0.02579     18
#           ...
# 0.02551      1
# 0.02556      1
# 0.02413      1
# 0.03383      1
# 0.02243      1
# Name: UCA, Length: 3200, dtype: int64
# Column name: UCG
# NANs: 0
# Negatives: 0
# Zeros: 551
# Positives: 11098
#
# 0.00000    551
# 0.00287     41
# 0.00239     38
# 0.01183     36
# 0.00262     26
#           ...
# 0.02506      1
# 0.02419      1
# 0.02396      1
# 0.02320      1
# 0.01841      1
# Name: UCG, Length: 2286, dtype: int64
# Column name: AGU
# NANs: 0
# Negatives: 0
# Zeros: 443
# Positives: 11206
#
# 0.00000    443
# 0.01381     43
# 0.00955     31
# 0.00288     29
# 0.00336     29
#           ...
# 0.02309      1
# 0.01960      1
# 0.02148      1
# 0.01993      1
# 0.00053      1
# Name: AGU, Length: 2418, dtype: int64
# Column name: AGC
# NANs: 0
# Negatives: 0
# Zeros: 167
# Positives: 11482
#
# 0.00000    167
# 0.00394     50
# 0.00478     42
# 0.00262     42
# 0.00860     30
#           ...
# 0.00236      1
# 0.00110      1
# 0.01993      1
# 0.02107      1
# 0.02553      1
# Name: AGC, Length: 2503, dtype: int64
# Column name: ACU
# NANs: 0
# Negatives: 0
# Zeros: 64
# Positives: 11585
#
# 0.00000    64
# 0.01183    42
# 0.03662    29
# 0.01587    22
# 0.01761    20
#            ..
# 0.02606     1
# 0.02748     1
# 0.00204     1
# 0.02877     1
# 0.03050     1
# Name: ACU, Length: 3200, dtype: int64
# Column name: ACC
# NANs: 0
# Negatives: 0
# Zeros: 70
# Positives: 11579
#
# 0.00000    70
# 0.00197    47
# 0.00955    38
# 0.00196    30
# 0.01081    16
#            ..
# 0.02705     1
# 0.03339     1
# 0.02210     1
# 0.01963     1
# 0.02451     1
# Name: ACC, Length: 4102, dtype: int64
# Column name: ACA
# NANs: 0
# Negatives: 0
# Zeros: 99
# Positives: 11550
#
# 0.00000    99
# 0.00197    43
# 0.02866    25
# 0.00196    22
# 0.01481    17
#            ..
# 0.04464     1
# 0.01861     1
# 0.01617     1
# 0.02061     1
# 0.03551     1
# Name: ACA, Length: 3910, dtype: int64
# Column name: ACG
# NANs: 0
# Negatives: 0
# Zeros: 454
# Positives: 11195
#
# 0.00000    454
# 0.00394     54
# 0.00318     43
# 0.00198     35
# 0.00287     32
#           ...
# 0.02104      1
# 0.02340      1
# 0.01804      1
# 0.02223      1
# 0.00928      1
# Name: ACG, Length: 2458, dtype: int64
# Column name: UAU
# NANs: 0
# Negatives: 0
# Zeros: 121
# Positives: 11528
#
# 0.00000    121
# 0.04536     31
# 0.00573     26
# 0.02787     25
# 0.00576     23
#           ...
# 0.00035      1
# 0.00227      1
# 0.00407      1
# 0.03462      1
# 0.00023      1
# Name: UAU, Length: 3886, dtype: int64
# Column name: UAC
# NANs: 0
# Negatives: 0
# Zeros: 36
# Positives: 11613
#
# 0.01433    53
# 0.00986    41
# 0.00000    36
# 0.01441    25
# 0.01719    24
#            ..
# 0.02510     1
# 0.04215     1
# 0.03086     1
# 0.03370     1
# 0.03237     1
# Name: UAC, Length: 2921, dtype: int64
# Column name: CAA
# NANs: 0
# Negatives: 0
# Zeros: 49
# Positives: 11600
#
# 0.00000    49
# 0.02367    46
# 0.03503    36
# 0.02579    20
# 0.01837    18
#            ..
# 0.04090     1
# 0.05575     1
# 0.03253     1
# 0.02600     1
# 0.01345     1
# Name: CAA, Length: 3623, dtype: int64
# Column name: CAG
# NANs: 0
# Negatives: 0
# Zeros: 264
# Positives: 11385
#
# 0.00000    264
# 0.00789     44
# 0.00262     30
# 0.00392     24
# 0.00287     23
#           ...
# 0.00745      1
# 0.03445      1
# 0.02392      1
# 0.03213      1
# 0.00839      1
# Name: CAG, Length: 3581, dtype: int64
# Column name: AAU
# NANs: 0
# Negatives: 0
# Zeros: 59
# Positives: 11590
#
# 0.00000    59
# 0.04536    38
# 0.04140    20
# 0.00860    20
# 0.00288    15
#            ..
# 0.05986     1
# 0.05301     1
# 0.04125     1
# 0.04802     1
# 0.01637     1
# Name: AAU, Length: 4578, dtype: int64
# Column name: AAC
# NANs: 0
# Negatives: 0
# Zeros: 22
# Positives: 11627
#
# 0.00986    40
# 0.02229    33
# 0.00000    22
# 0.01433    20
# 0.02006    20
#            ..
# 0.00732     1
# 0.00695     1
# 0.00714     1
# 0.04175     1
# 0.05755     1
# Name: AAC, Length: 3598, dtype: int64
# Column name: UGU
# NANs: 0
# Negatives: 0
# Zeros: 714
# Positives: 10935
#
# 0.00000    714
# 0.00986     52
# 0.01592     30
# 0.00168     28
# 0.00224     27
#           ...
# 0.02252      1
# 0.01781      1
# 0.02039      1
# 0.01514      1
# 0.02927      1
# Name: UGU, Length: 2194, dtype: int64
# Column name: UGC
# NANs: 0
# Negatives: 0
# Zeros: 496
# Positives: 11153
#
# 0.00000    496
# 0.00287     57
# 0.00196     37
# 0.00197     31
# 0.00288     31
#           ...
# 0.01959      1
# 0.01782      1
# 0.01337      1
# 0.02163      1
# 0.02716      1
# Name: UGC, Length: 2135, dtype: int64
# Column name: CAU
# NANs: 0
# Negatives: 0
# Zeros: 138
# Positives: 11511
#
# 0.00000    138
# 0.01035     43
# 0.00860     38
# 0.03353     28
# 0.00573     25
#           ...
# 0.02268      1
# 0.01940      1
# 0.02734      1
# 0.00226      1
# 0.00025      1
# Name: CAU, Length: 2591, dtype: int64
# Column name: CAC
# NANs: 0
# Negatives: 0
# Zeros: 84
# Positives: 11565
#
# 0.00000    84
# 0.00789    47
# 0.00159    37
# 0.01433    22
# 0.00783    20
#            ..
# 0.02072     1
# 0.00017     1
# 0.00169     1
# 0.02225     1
# 0.02753     1
# Name: CAC, Length: 2588, dtype: int64
# Column name: AAA
# NANs: 0
# Negatives: 0
# Zeros: 55
# Positives: 11594
#
# 0.00000    55
# 0.04339    35
# 0.02548    27
# 0.02362    26
# 0.02579    21
#            ..
# 0.00817     1
# 0.09140     1
# 0.05575     1
# 0.04083     1
# 0.01797     1
# Name: AAA, Length: 5142, dtype: int64
# Column name: AAG
# NANs: 0
# Negatives: 0
# Zeros: 272
# Positives: 11377
#
# 0.00000    272
# 0.01972     36
# 0.02070     32
# 0.00262     26
# 0.00168     20
#           ...
# 0.04540      1
# 0.01075      1
# 0.00959      1
# 0.05341      1
# 0.00116      1
# Name: AAG, Length: 4405, dtype: int64
# Column name: CGU
# NANs: 0
# Negatives: 0
# Zeros: 419
# Positives: 11230
#
# 0.00000    419
# 0.00287     67
# 0.00557     42
# 0.00319     33
# 0.00168     32
#           ...
# 0.02203      1
# 0.02001      1
# 0.01663      1
# 0.01934      1
# 0.00023      1
# Name: CGU, Length: 2212, dtype: int64
# Column name: CGC
# NANs: 0
# Negatives: 0
# Zeros: 450
# Positives: 11199
#
# 0.00000    450
# 0.00592     49
# 0.00288     48
# 0.00239     45
# 0.00196     42
#           ...
# 0.04595      1
# 0.03208      1
# 0.05265      1
# 0.03321      1
# 0.01512      1
# Name: CGC, Length: 3102, dtype: int64
# Column name: CGA
# NANs: 0
# Negatives: 0
# Zeros: 325
# Positives: 11324
#
# 0.00000    325
# 0.00318     43
# 0.00319     38
# 0.00576     37
# 0.01578     24
#           ...
# 0.01705      1
# 0.01450      1
# 0.01443      1
# 0.02544      1
# 0.01208      1
# Name: CGA, Length: 1808, dtype: int64
# Column name: CGG
# NANs: 0
# Negatives: 0
# Zeros: 1046
# Positives: 10603
#
# 0.00000    1046
# 0.00394      56
# 0.00159      42
# 0.00280      34
# 0.00057      34
#            ...
# 0.04070       1
# 0.03282       1
# 0.03625       1
# 0.02526       1
# 0.00925       1
# Name: CGG, Length: 2079, dtype: int64
# Column name: AGA
# NANs: 0
# Negatives: 0
# Zeros: 1588
# Positives: 10061
#
# 0.00000    1588
# 0.02170      37
# 0.01587      24
# 0.00032      23
# 0.01115      22
#            ...
# 0.03424       1
# 0.02168       1
# 0.01419       1
# 0.02136       1
# 0.00962       1
# Name: AGA, Length: 2799, dtype: int64
# Column name: AGG
# NANs: 0
# Negatives: 0
# Zeros: 1595
# Positives: 10054
#
# 0.00000    1595
# 0.00986      43
# 0.00391      37
# 0.00056      36
# 0.01035      33
#            ...
# 0.02708       1
# 0.02563       1
# 0.01742       1
# 0.02333       1
# 0.02368       1
# Name: AGG, Length: 2166, dtype: int64
# Column name: GAU
# NANs: 0
# Negatives: 0
# Zeros: 246
# Positives: 11403
#
# 0.00000    246
# 0.02367     41
# 0.03901     31
# 0.00287     25
# 0.00262     19
#           ...
# 0.03155      1
# 0.04041      1
# 0.05027      1
# 0.03554      1
# 0.00046      1
# Name: GAU, Length: 4408, dtype: int64
# Column name: GAC
# NANs: 0
# Negatives: 0
# Zeros: 109
# Positives: 11540
#
# 0.00000    109
# 0.00789     44
# 0.00287     37
# 0.01911     28
# 0.00992     26
#           ...
# 0.05274      1
# 0.03358      1
# 0.04321      1
# 0.04133      1
# 0.03452      1
# Name: GAC, Length: 4335, dtype: int64
# Column name: GAA
# NANs: 0
# Negatives: 0
# Zeros: 14
# Positives: 11635
#
# 0.01433    41
# 0.03353    35
# 0.01837    27
# 0.01831    26
# 0.01153    24
#            ..
# 0.03865     1
# 0.03324     1
# 0.04104     1
# 0.03440     1
# 0.01608     1
# Name: GAA, Length: 4689, dtype: int64
# Column name: GAG
# NANs: 0
# Negatives: 0
# Zeros: 298
# Positives: 11351
#
# 0.00000    298
# 0.01381     36
# 0.01672     32
# 0.00978     19
# 0.00287     18
#           ...
# 0.04888      1
# 0.04640      1
# 0.04211      1
# 0.03155      1
# 0.00188      1
# Name: GAG, Length: 4526, dtype: int64
# Column name: UAA
# NANs: 0
# Negatives: 0
# Zeros: 1482
# Positives: 10167
#
# 0.00000    1482
# 0.00046     117
# 0.00287      96
# 0.00080      82
# 0.00073      72
#            ...
# 0.00849       1
# 0.00533       1
# 0.00645       1
# 0.02411       1
# 0.01532       1
# Name: UAA, Length: 675, dtype: int64
# Column name: UAG
# NANs: 0
# Negatives: 0
# Zeros: 3716
# Positives: 7933
#
# 0.00000    3716
# 0.00056     111
# 0.00090     107
# 0.00044     102
# 0.00047      97
#            ...
# 0.00414       1
# 0.01250       1
# 0.00410       1
# 0.01142       1
# 0.00630       1
# Name: UAG, Length: 418, dtype: int64
# Column name: UGA
# NANs: 0
# Negatives: 0
# Zeros: 2087
# Positives: 9562
#
# 0.00000    2087
# 0.00197      98
# 0.00090      78
# 0.00196      69
# 0.00040      68
#            ...
# 0.02008       1
# 0.01893       1
# 0.00790       1
# 0.02183       1
# 0.02556       1
# Name: UGA, Length: 1604, dtype: int64

# %%
df
# Out:
#        Kingdom  DNAtype  Ncodons      UUU      UUC      UUA      UUG      CUU  \
# 0            9        0     1995  0.01654  0.01203  0.00050  0.00351  0.01203
# 1            9        0     1474  0.02714  0.01357  0.00068  0.00678  0.00407
# 2            9        0     4862  0.01974  0.02180  0.01357  0.01543  0.00782
# 3            9        0     1915  0.01775  0.02245  0.01619  0.00992  0.01567
# 4            9        0    22831  0.02816  0.01371  0.00767  0.03679  0.01380
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 12056       10        1     1549  0.01679  0.03228  0.03486  0.00194  0.05939
# 12057       10        0     8062  0.02270  0.01079  0.01191  0.01662  0.01240
# 12058       10        1     4309  0.03087  0.02367  0.00162  0.00000  0.00209
# 12059       10        0   106417  0.01666  0.02917  0.00469  0.01083  0.00876
# 12060       10        1     4304  0.02881  0.04089  0.01789  0.00953  0.02695
#
#            CUC      CUA  ...      CGG      AGA      AGG      GAU      GAC  \
# 0      0.03208  0.00100  ...  0.00451  0.01303  0.03559  0.01003  0.04612
# 1      0.02849  0.00204  ...  0.00136  0.01696  0.03596  0.01221  0.04545
# 2      0.01111  0.01028  ...  0.00596  0.01974  0.02489  0.03126  0.02036
# 3      0.01358  0.00940  ...  0.00366  0.01410  0.01671  0.03760  0.01932
# 4      0.00548  0.00473  ...  0.00604  0.01494  0.01734  0.04148  0.02483
# ...        ...      ...  ...      ...      ...      ...      ...      ...
# 12056  0.04906  0.07037  ...  0.00000  0.00000  0.00000  0.00000  0.00323
# 12057  0.00670  0.00521  ...  0.00360  0.01898  0.00558  0.04478  0.01526
# 12058  0.05082  0.06173  ...  0.00000  0.00000  0.00000  0.00046  0.00186
# 12059  0.02408  0.00359  ...  0.00925  0.01147  0.01630  0.01258  0.03217
# 12060  0.04229  0.05855  ...  0.00279  0.00000  0.00070  0.00395  0.01580
#
#            GAA      GAG      UAA      UAG      UGA
# 0      0.01203  0.04361  0.00251  0.00050  0.00000
# 1      0.01560  0.04410  0.00271  0.00068  0.00000
# 2      0.02242  0.02468  0.00391  0.00000  0.00144
# 3      0.03029  0.03446  0.00261  0.00157  0.00000
# 4      0.03359  0.03679  0.00000  0.00044  0.00131
# ...        ...      ...      ...      ...      ...
# 12056  0.01937  0.00581  0.00516  0.00000  0.02905
# 12057  0.04317  0.02444  0.00136  0.00012  0.00112
# 12058  0.01764  0.00000  0.01532  0.00000  0.07890
# 12059  0.01540  0.03919  0.00060  0.00039  0.00144
# 12060  0.01812  0.00581  0.00232  0.00046  0.02556
#
# [11649 rows x 67 columns]

# %% [markdown]
# ### **Transformations**

# %% [markdown]
# #### Train-test split

# %%
X = df.drop(["Kingdom",	"DNAtype"], axis=1)
y = df["Kingdom"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# #### Balancing

# %% [markdown]
# #### Transformation

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Feature selection

# %% [markdown]
# ## **Model Classifier**

# %% [markdown]
# Extra Trees, Gradient Boosting, Hist Gradient Boosting,
# Stacking, y Voting.

# %%
EXPERIMENT_NAME = "test2" # Before create name in MLflow UI
DATASET = "Kingdom"
RUN_NAME = "first"
# Out:
# time: 992 µs (started: 2022-06-26 14:14:14 -05:00)

# %% [markdown]
# ### **Random Forest Classifier**

# %% [markdown]
# #### Tuning the hyper-parameters

# %%
param_grid = {
    "criterion": ["gini", "entropy"], 
    "max_depth": range(2, 20, 2),
    # "min_samples_split": [2, 4, 8],
    # "max_features": ["auto", "sqrt", "log2"],
    # "max_leaf_nodes": [2, 4, 8, None],
    # "class_weight": ["balanced", "balanced_subsample", None],
    "max_samples": [0.3, 0.5, 0.6]
}

# %% [markdown]
# #### HalvingGridSearchCV

# %%
clf = RandomForestClassifier(random_state=1)
hgs = HalvingGridSearchCV(estimator=clf,
                         param_grid=param_grid,
                         resource="n_estimators",
                         max_resources=100,
                         cv=5,
                         scoring="accuracy",
                         random_state=42,
                         n_jobs=-1)
hgs.fit(X_train, y_train)
print(hgs.best_score_)
print(hgs.score(X_train, y_train))
print(hgs.score(X_test, y_test))
hgs.best_params_
# Out:
# 0.8860066586004287
# 0.998939145529945
# 0.8885460856151176
# {'criterion': 'entropy',
#  'max_depth': 16,
#  'max_samples': 0.6,
#  'n_estimators': 81}

# %% [markdown]
# #### HalvingRandomSearchCV

# %%
clf = RandomForestClassifier(random_state=1)
np.random.seed(1)

hrs = HalvingRandomSearchCV(estimator=clf,
                           param_distributions=param_grid,
                           resource="n_estimators",
                           max_resources=100,
                           cv=5,
                           scoring="accuracy",
                           random_state=42,
                           n_jobs=-1)
hrs.fit(X_train, y_train)
print(hrs.best_score_)
print(hrs.score(X_train, y_train))
print(hrs.score(X_test, y_test))
hrs.best_params_

# %% [markdown]
# #### GridSearchCV

# %%
clf = RandomForestClassifier(random_state=1)
gs = GridSearchCV(estimator=clf, 
                  param_grid=param_grid, 
                  scoring="accuracy",
                  n_jobs=-1,
                  cv=5,
                  verbose=2)
gs.fit(X_train, y_train)
print(gs.best_score_)
print(gs.score(X_train, y_train))
print(gs.score(X_test, y_test))
gs.best_params_
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# 0.9203773391479431
# 0.9994634617448224
# 0.91931330472103
# {'criterion': 'entropy', 'max_depth': 18, 'max_samples': 0.6}

# %% [markdown]
# #### RandomizedSearchCV

# %%
clf = RandomForestClassifier(random_state=1)
rs = RandomizedSearchCV(estimator=clf, 
                        param_distributions=param_grid, 
                        n_iter=20,
                        scoring="accuracy",
                        n_jobs=-1,
                        cv=5,
                        random_state=42)
rs.fit(X_train, y_train)
print(rs.best_score_)
print(rs.score(X_train, y_train))
print(rs.score(X_test, y_test))
pprint(rs.best_params_)

# %% [markdown]
# #### Select best/Validation

# %%
model = gs.best_estimator_

df_val = validation_multi(model, X_train, y_train, X_test, y_test)
df_val.head()
# Out:
#        Accuracy  Precision    Recall       AUC     Cross
# Train  0.999463   0.999463  0.999463  0.999999  0.920377
# Test   0.919313   0.919313  0.919313  0.991940  0.866524

# %% [markdown]
# #### MLflow Tracking

# %%
client = MlflowClient()
experiment_id = client.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

with mlflow.start_run(experiment_id=experiment_id, run_name=RUN_NAME):
    run = mlflow.active_run()
    print("Active run_id: {}".format(run.info.run_id))

    mlflow.log_params(gs.best_params_)
    mlflow.log_metrics(get_metrics(df_val))
    mlflow.set_tags({"Estimator": str(gs.estimator.base_estimator), "Dataset": DATASET})
# Out:
# Active run_id: da7a62c0caba4944a0d3168810214630

# %% [markdown]
# ### **Extra Trees**

# %% [markdown]
# #### Tuning the hyper-parameters

# %%
param_grid = {
    # "n_estimators": np.arange(10, 300, 50),
    ##"criterion": ["gini", "entropy", "log_loss"], 
    "max_depth": np.arange(2, 21, 2),
    # "min_samples_split": [2, 4, 8],
    # "max_features": ["auto", "sqrt", "log2"],
    "max_leaf_nodes": [2, 4, 8, None],
    "bootstrap": [True],
    # "class_weight": ["balanced", "balanced_subsample", None],
    "max_samples": [0.3, 0.5, 0.6, 1.0]
}
# Out:
# time: 1.5 ms (started: 2022-06-26 19:57:56 -05:00)

# %% [markdown]
# #### MLflow tracking + Grid search

# %%
client = MlflowClient()
experiment_id = client.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

with mlflow.start_run(experiment_id=experiment_id, run_name=RUN_NAME):
    run = mlflow.active_run()
    print("Active run_id: {}".format(run.info.run_id))

    et = ExtraTreesClassifier(random_state=42)
    gs_et = GridSearchCV(estimator=et, 
                         param_grid=param_grid, 
                         scoring="roc_auc_ovr",
                         n_jobs=-1,
                         cv=5,
                         verbose=1,
                         error_score="raise")
    gs_et.fit(X_train, y_train)

    best_gs_et = gs_et.best_estimator_
    df_val_et = validation_multi(best_gs_et, X_train, y_train, X_test, y_test)

    mlflow.log_params(gs_et.best_params_)
    mlflow.log_metrics(get_metrics(df_val_et))
    mlflow.set_tags({"Estimator": str(gs_et.estimator), "Dataset": DATASET})
# Out:
# Active run_id: 5feb8b7819e14ea69ceb3b5a4b271dc0
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# time: 18.5 s (started: 2022-06-26 19:57:56 -05:00)

# %% [markdown]
# ### **Gradient Boosting**

# %% [markdown]
# #### Tuning the hyper-parameters

# %%
param_grid = {
    ##"loss": ["log_loss", "deviance", "exponential"],
    # "learning_rate": [0.001, 0.01, 0.1, 0.3, 1.0],
    #"n_estimators": np.arange(10, 101, 10),
    ##"criterion": ["friedman_mse", "squared_error", "mse"], 
    # "min_samples_split": [2, 4, 8],
    "max_depth": np.arange(2, 21, 2),
    # "max_features": ["auto", "sqrt", "log2"],
    ##"max_leaf_nodes": [2, 4, 8, None],
}
# Out:
# time: 1.07 ms (started: 2022-06-26 16:16:09 -05:00)

# %% [markdown]
# #### MLflow tracking + Grid search

# %%
client = MlflowClient()
experiment_id = client.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

with mlflow.start_run(experiment_id=experiment_id, run_name=RUN_NAME):
    run = mlflow.active_run()
    print("Active run_id: {}".format(run.info.run_id))

    gb = GradientBoostingClassifier(random_state=42)
    gs_gb = GridSearchCV(estimator=gb, 
                         param_grid=param_grid, 
                         scoring="roc_auc_ovr",
                         n_jobs=-1,
                         cv=5,
                         verbose=1)
    gs_gb.fit(X_train, y_train)

    best_gs_gb = gs_gb.best_estimator_
    df_val_gb = validation_multi(best_gs_gb, X_train, y_train, X_test, y_test)

    mlflow.log_params(gs_gb.best_params_)
    mlflow.log_metrics(get_metrics(df_val_gb))
    mlflow.set_tags({"Estimator": str(gs_gb.estimator), "Dataset": DATASET})
# Out:
# Active run_id: 967f1cbe739a416e90d931b0c3f371f6
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# time: 22min 50s (started: 2022-06-26 16:16:22 -05:00)

# %% [markdown]
# ### **Hist Gradient Boosting**

# %% [markdown]
# #### Tuning the hyper-parameters

# %%
param_grid = {
    # "loss": ["log_loss", "auto", "binary_crossentropy", "categorical_crossentropy"],
    # "learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.3, 1.0],
    "max_iter": np.arange(10, 101, 10),
    "max_depth": np.arange(2, 21, 2)
}
# Out:
# time: 878 µs (started: 2022-06-26 19:58:14 -05:00)

# %% [markdown]
# #### MLflow tracking + Grid search

# %%
client = MlflowClient()
experiment_id = client.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

with mlflow.start_run(experiment_id=experiment_id, run_name=RUN_NAME):
    run = mlflow.active_run()
    print("Active run_id: {}".format(run.info.run_id))

    hgb = HistGradientBoostingClassifier(random_state=42)
    gs_hgb = GridSearchCV(estimator=hgb, 
                          param_grid=param_grid, 
                          scoring="roc_auc_ovr",
                          n_jobs=-1,
                          cv=5,
                          verbose=1)
    gs_hgb.fit(X_train, y_train)

    best_gs_hgb = gs_hgb.best_estimator_
    df_val_hgb = validation_multi(best_gs_hgb, X_train, y_train, X_test, y_test)

    mlflow.log_params(gs_hgb.best_params_)
    mlflow.log_metrics(get_metrics(df_val_hgb))
    mlflow.set_tags({"Estimator": str(gs_hgb.estimator), "Dataset": DATASET})
# Out:
# Active run_id: fef0697344e64170a4e9a6b71f012a68
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# time: 2min 9s (started: 2022-06-26 19:58:14 -05:00)

# %% [markdown]
# ### **Stacking**

# %% [markdown]
# #### Tuning the hyper-parameters

# %%
param_grid = {
    "loss": ["log_loss", "auto", "binary_crossentropy", "categorical_crossentropy"],
    "learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.3, 1.0],
    "max_iter": np.arange(10, 101, 10),
    "max_depth": np.arange(2, 21, 2)
}
# Out:
# time: 537 µs (started: 2022-06-26 20:00:24 -05:00)

# %% [markdown]
# #### MLflow tracking + Grid search

# %%
client = MlflowClient()
experiment_id = client.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

with mlflow.start_run(experiment_id=experiment_id, run_name=RUN_NAME):
    run = mlflow.active_run()
    print("Active run_id: {}".format(run.info.run_id))

    clf1 = DecisionTreeClassifier(max_depth=4)
    clf2 = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=7))
    clf3 = make_pipeline(StandardScaler(), SVC(kernel="rbf", probability=True))

    stacking = StackingClassifier(estimators=[("dt", clf1), ("knn", clf2), ("svc", clf3)], 
                                  final_estimator=LogisticRegression(penalty="l2"),
                                  n_jobs=-1)
    stacking.fit(X_train, y_train)

    df_val_stacking = validation_multi(stacking, X_train, y_train, X_test, y_test)

    mlflow.log_params(stacking.final_estimator_.get_params())
    mlflow.log_metrics(get_metrics(df_val_stacking))
    mlflow.set_tags({"Estimator": ",".join(list(stacking.named_estimators_.keys())), "Dataset": DATASET})
# Out:
# Active run_id: fce66283a9e047d0ac1877a2cf56dadc
# time: 1min 19s (started: 2022-06-26 20:00:24 -05:00)

# %% [markdown]
# ### **Voting**

# %% [markdown]
# #### Tuning the hyper-parameters

# %%
param_grid = {
    "loss": ["log_loss", "auto", "binary_crossentropy", "categorical_crossentropy"],
    "learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.3, 1.0],
    "max_iter": np.arange(10, 101, 10),
    "max_depth": np.arange(2, 21, 2)
}
# Out:
# time: 554 µs (started: 2022-06-26 20:01:43 -05:00)

# %% [markdown]
# #### MLflow tracking + Grid search

# %%
client = MlflowClient()
experiment_id = client.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

with mlflow.start_run(experiment_id=experiment_id, run_name=RUN_NAME):
    run = mlflow.active_run()
    print("Active run_id: {}".format(run.info.run_id))

    clf1 = DecisionTreeClassifier(max_depth=4)
    clf2 = KNeighborsClassifier(n_neighbors=7)
    clf3 = SVC(gamma=0.1, kernel="rbf", probability=True)
    
    voting = VotingClassifier(estimators=[("dt", clf1), ("knn", clf2), ("svc", clf3)],
                              voting="soft", weights=[2, 1, 2], n_jobs=-1)
    voting.fit(X_train, y_train)

    df_val_voting = validation_multi(voting, X_train, y_train, X_test, y_test)

    mlflow.log_params({})
    mlflow.log_metrics(get_metrics(df_val_voting))
    mlflow.set_tags({"Estimator": ",".join(list(voting.named_estimators_.keys())), "Dataset": DATASET})
# Out:
# Active run_id: b1194b47d7804d91b2b60dd75d1f29aa
# time: 2min 14s (started: 2022-06-26 20:25:47 -05:00)
